# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/drw-crypto-market-prediction/sample_submission.csv
# /kaggle/input/drw-crypto-market-prediction/train.parquet
# /kaggle/input/drw-crypto-market-prediction/test.parquet

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from scipy.stats import pearsonr

class CFG:
    train_path = "/kaggle/input/drw-crypto-market-prediction/train.parquet"
    test_path = "/kaggle/input/drw-crypto-market-prediction/test.parquet"
    sample_sub_path = "/kaggle/input/drw-crypto-market-prediction/sample_submission.csv"

def reduce_mem_usage(dataframe, dataset):    
    print('Reducing memory usage for:', dataset)
    initial_mem_usage = dataframe.memory_usage().sum() / 1024**2
    
    for col in dataframe.columns:
        col_type = dataframe[col].dtype

        c_min = dataframe[col].min()
        c_max = dataframe[col].max()
        if str(col_type)[:3] == 'int':
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                dataframe[col] = dataframe[col].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                dataframe[col] = dataframe[col].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                dataframe[col] = dataframe[col].astype(np.int32)
            elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                dataframe[col] = dataframe[col].astype(np.int64)
        else:
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                dataframe[col] = dataframe[col].astype(np.float16)
            elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                dataframe[col] = dataframe[col].astype(np.float32)
            else:
                dataframe[col] = dataframe[col].astype(np.float64)

    final_mem_usage = dataframe.memory_usage().sum() / 1024**2
    print('--- Memory usage before: {:.2f} MB'.format(initial_mem_usage))
    print('--- Memory usage after: {:.2f} MB'.format(final_mem_usage))
    print('--- Decreased memory usage by {:.1f}%\n'.format(100 * (initial_mem_usage - final_mem_usage) / initial_mem_usage))

    return dataframe

# Create time-based sample weights
def create_time_weights(n_samples, decay_factor=0.95):
    """
    Create exponentially decaying weights based on sample position.
    More recent samples (higher indices) get higher weights.
    decay_factor controls the rate of decay (0.95 = 5% decay per time unit)
    """
    positions = np.arange(n_samples)
    # Normalize positions to [0, 1] range
    normalized_positions = positions / (n_samples - 1)
    # Apply exponential weighting
    weights = decay_factor ** (1 - normalized_positions)
    # Normalize weights to sum to n_samples (maintains scale)
    weights = weights * n_samples / weights.sum()
    return weights

# Load data
train = pd.read_parquet(CFG.train_path).reset_index(drop=True)
test = pd.read_parquet(CFG.test_path).reset_index(drop=True)
sample = pd.read_csv(CFG.sample_sub_path)

# Select features
selected_features = [
    "X863", "X856", "X344", "X598", "X862", "X385", "X852", "X603", "X860", "X674",
    "X415", "X345", "X137", "X855", "X174", "X302", "X178", "X532", "X168", "X612",
    "bid_qty", "ask_qty", "buy_qty", "sell_qty", "volume"
]

train = train[selected_features + ["label"]]
test = test[selected_features]

train = reduce_mem_usage(train, "train")
test = reduce_mem_usage(test, "test")

print("Train=", train.shape)
print("Test=", test.shape)
print("Sample=", sample.shape)

RMV = ["label"]
FEATURES = [c for c in train.columns if c not in RMV]
print(f"There are {len(FEATURES)} FEATURES: {FEATURES}")

# Define cross-validation
FOLDS = 5
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# XGBoost parameters (same for all models)
xgb_params = {
    "tree_method": "gpu_hist",
    "colsample_bylevel": 0.4778015829774066,
    "colsample_bynode": 0.362764358742407,
    "colsample_bytree": 0.7107423488010493,
    "gamma": 1.7094857725240398,
    "learning_rate": 0.02213323588455387,
    "max_depth": 20,
    "max_leaves": 12,
    "min_child_weight": 16,
    "n_estimators": 1667,
    "n_jobs": -1,
    "random_state": 42,
    "reg_alpha": 39.352415706891264,
    "reg_lambda": 75.44843704068275,
    "subsample": 0.06566669853471274,
    "verbosity": 0
}

# Define model configurations
model_configs = [
    {"name": "Model 1 (100% Full Data)", "percent": 1.00},
    {"name": "Model 2 (90% Recent)", "percent": 0.90},
    {"name": "Model 3 (80% Recent)", "percent": 0.80},
    {"name": "Model 4 (70% Recent)", "percent": 0.70},
    {"name": "Model 5 (60% Recent)", "percent": 0.60},
    {"name": "Model 6 (50% Recent)", "percent": 0.50},
    {"name": "Model 7 (40% Recent)", "percent": 0.40}
]

# Initialize predictions for all models
n_models = len(model_configs)
oof_preds_all = [np.zeros(len(train)) for _ in range(n_models)]
test_preds_all = [np.zeros(len(test)) for _ in range(n_models)]

# Generate sample weights for Model 1 (full data)
sample_weights_full = create_time_weights(len(train), decay_factor=0.95)
print(f"\nModel 1 - Full data sample weights range: [{sample_weights_full.min():.4f}, {sample_weights_full.max():.4f}]")
print(f"Model 1 - Full data sample weights mean: {sample_weights_full.mean():.4f}")

# Calculate cutoffs for each model
cutoffs = []
for config in model_configs:
    if config["percent"] == 1.00:
        cutoffs.append(0)  # Full data starts from index 0
    else:
        cutoff_idx = int(len(train) * (1 - config["percent"]))
        cutoffs.append(cutoff_idx)
        print(f"\n{config['name']} - Using most recent {len(train) - cutoff_idx} samples ({int(config['percent']*100)}% of data)")

# Cross-validation loop
for fold_num, (train_idx, valid_idx) in enumerate(kf.split(train)):
    print("\n" + "#" * 50)
    print(f"### Fold {fold_num + 1}")
    print("#" * 50)
    
    X_valid = train.iloc[valid_idx][FEATURES]
    y_valid = train.iloc[valid_idx]["label"]
    X_test = test[FEATURES]
    
    # Train each model
    for model_idx, (config, cutoff) in enumerate(zip(model_configs, cutoffs)):
        print(f"\n--- {config['name']} ---")
        
        if config["percent"] == 1.00:
            # Model 1: Full data with time weights
            X_train = train.iloc[train_idx][FEATURES]
            y_train = train.iloc[train_idx]["label"]
            
            # Extract sample weights for this fold's training data
            train_weights = sample_weights_full[train_idx]
            
        else:
            # Other models: Recent data subsets
            # Filter train indices to only include those from the recent data
            train_idx_recent = train_idx[train_idx >= cutoff]
            
            # Adjust indices to start from 0 for the recent subset
            train_idx_recent_adjusted = train_idx_recent - cutoff
            
            # Get the recent subset of training data
            train_recent = train.iloc[cutoff:].reset_index(drop=True)
            
            X_train = train_recent.iloc[train_idx_recent_adjusted][FEATURES]
            y_train = train_recent.iloc[train_idx_recent_adjusted]["label"]
            
            # Create time weights for the recent data subset
            sample_weights_recent = create_time_weights(len(train_recent), decay_factor=0.95)
            train_weights = sample_weights_recent[train_idx_recent_adjusted]
        
        # Train the model
        model = XGBRegressor(**xgb_params)
        model.fit(
            X_train, y_train,
            sample_weight=train_weights,
            eval_set=[(X_valid, y_valid)],
            early_stopping_rounds=25,
            verbose=200
        )
        
        # Make predictions
        if config["percent"] == 1.00:
            # Model 1 predicts for all validation indices
            oof_preds_all[model_idx][valid_idx] = model.predict(X_valid)
        else:
            # Other models: handle validation indices that might be outside their training range
            valid_idx_in_range = valid_idx[valid_idx >= cutoff]
            if len(valid_idx_in_range) > 0:
                X_valid_subset = train.iloc[valid_idx_in_range][FEATURES]
                oof_preds_all[model_idx][valid_idx_in_range] = model.predict(X_valid_subset)
            
            # For indices before cutoff, use Model 1 predictions
            valid_idx_out_range = valid_idx[valid_idx < cutoff]
            if len(valid_idx_out_range) > 0:
                oof_preds_all[model_idx][valid_idx_out_range] = oof_preds_all[0][valid_idx_out_range]
        
        test_preds_all[model_idx] += model.predict(X_test)

# Average test predictions across folds
for i in range(n_models):
    test_preds_all[i] /= FOLDS

# Calculate individual model scores
pearson_scores = []
for i, config in enumerate(model_configs):
    score = pearsonr(train["label"], oof_preds_all[i])[0]
    pearson_scores.append(score)

print("\n" + "=" * 50)
print("INDIVIDUAL MODEL PERFORMANCE")
print("=" * 50)
for config, score in zip(model_configs, pearson_scores):
    print(f"{config['name']} Pearson Correlation: {score:.4f}")

# Create ensemble predictions
# Simple average ensemble
ensemble_oof_preds = np.mean(oof_preds_all, axis=0)
ensemble_test_preds = np.mean(test_preds_all, axis=0)

# Calculate ensemble score
ensemble_pearson_score = pearsonr(train["label"], ensemble_oof_preds)[0]

print("\n" + "=" * 50)
print("ENSEMBLE PERFORMANCE")
print("=" * 50)
print(f"Ensemble (Equal Weight) Pearson Correlation: {ensemble_pearson_score:.4f}")

# Performance-weighted ensemble
total_score = sum(pearson_scores)
weights = [score / total_score for score in pearson_scores]

weighted_ensemble_oof = np.zeros(len(train))
weighted_ensemble_test = np.zeros(len(test))

for i in range(n_models):
    weighted_ensemble_oof += weights[i] * oof_preds_all[i]
    weighted_ensemble_test += weights[i] * test_preds_all[i]

weighted_ensemble_score = pearsonr(train["label"], weighted_ensemble_oof)[0]

print(f"\nWeighted Ensemble Performance:")
for config, weight in zip(model_configs, weights):
    print(f"  {config['name']} weight: {weight:.3f}")
print(f"  Weighted Ensemble Pearson Correlation: {weighted_ensemble_score:.4f}")

# Use the better ensemble for final predictions
if weighted_ensemble_score > ensemble_pearson_score:
    final_test_preds = weighted_ensemble_test
    print("\nUsing weighted ensemble for final predictions")
else:
    final_test_preds = ensemble_test_preds
    print("\nUsing simple average ensemble for final predictions")

# SHAP analysis (using Model 1 as representative)
print("\nGenerating SHAP analysis...")
# Note: We need to retrain model1 for SHAP since we're outside the CV loop
model1_for_shap = XGBRegressor(**xgb_params)
model1_for_shap.fit(
    train[FEATURES], train["label"],
    sample_weight=sample_weights_full,
    verbose=0
)
explainer = shap.TreeExplainer(model1_for_shap, feature_perturbation="tree_path_dependent", model_output="raw")
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)

# Save predictions
sample["prediction"] = final_test_preds
sample.to_csv("submission.csv", index=False)
print("\nPredictions saved to submission.csv")
print(sample.head())

# Save detailed results
results_data = {
    'model': [config['name'] for config in model_configs] + ['Simple Ensemble', 'Weighted Ensemble'],
    'pearson_correlation': pearson_scores + [ensemble_pearson_score, weighted_ensemble_score],
    'weight_in_final': [weight if weighted_ensemble_score > ensemble_pearson_score else 1/n_models 
                        for weight in weights] + [np.nan, np.nan]
}

ensemble_results = pd.DataFrame(results_data)
ensemble_results.to_csv("ensemble_results.csv", index=False)
print("\nEnsemble results saved to ensemble_results.csv")
print(ensemble_results)
# Out:
# Reducing memory usage for: train
# --- Memory usage before: 104.32 MB
# --- Memory usage after: 26.08 MB
# --- Decreased memory usage by 75.0%
#
# Reducing memory usage for: test
# --- Memory usage before: 102.64 MB
# --- Memory usage after: 25.66 MB
# --- Decreased memory usage by 75.0%
#
# Train= (525887, 26)
# Test= (538150, 25)
# Sample= (538150, 2)
# There are 25 FEATURES: ['X863', 'X856', 'X344', 'X598', 'X862', 'X385', 'X852', 'X603', 'X860', 'X674', 'X415', 'X345', 'X137', 'X855', 'X174', 'X302', 'X178', 'X532', 'X168', 'X612', 'bid_qty', 'ask_qty', 'buy_qty', 'sell_qty', 'volume']
#
# Model 1 - Full data sample weights range: [0.9746, 1.0259]
# Model 1 - Full data sample weights mean: 1.0000
#
# Model 2 (90% Recent) - Using most recent 473299 samples (90% of data)
#
# Model 3 (80% Recent) - Using most recent 420710 samples (80% of data)
#
# Model 4 (70% Recent) - Using most recent 368121 samples (70% of data)
#
# Model 5 (60% Recent) - Using most recent 315533 samples (60% of data)
#
# Model 6 (50% Recent) - Using most recent 262944 samples (50% of data)
#
# Model 7 (40% Recent) - Using most recent 210355 samples (40% of data)
#
# ##################################################
# ### Fold 1
# ##################################################
#
# --- Model 1 (100% Full Data) ---
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.01616
# [200]	validation_0-rmse:0.98606
# [400]	validation_0-rmse:0.96835
# [600]	validation_0-rmse:0.95501
# [800]	validation_0-rmse:0.94363
# [1000]	validation_0-rmse:0.93393
# [1200]	validation_0-rmse:0.92539
# [1400]	validation_0-rmse:0.91818
# [1600]	validation_0-rmse:0.91154
# [1666]	validation_0-rmse:0.90956
#
# --- Model 2 (90% Recent) ---
# [0]	validation_0-rmse:1.01617
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98770
# [400]	validation_0-rmse:0.97105
# [600]	validation_0-rmse:0.95777
# [800]	validation_0-rmse:0.94700
# [1000]	validation_0-rmse:0.93860
# [1200]	validation_0-rmse:0.93066
# [1400]	validation_0-rmse:0.92380
# [1600]	validation_0-rmse:0.91770
# [1666]	validation_0-rmse:0.91599
#
# --- Model 3 (80% Recent) ---
# [0]	validation_0-rmse:1.01618
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98870
# [400]	validation_0-rmse:0.97210
# [600]	validation_0-rmse:0.96027
# [800]	validation_0-rmse:0.95032
# [1000]	validation_0-rmse:0.94223
# [1200]	validation_0-rmse:0.93517
# [1400]	validation_0-rmse:0.92916
# [1600]	validation_0-rmse:0.92338
# [1666]	validation_0-rmse:0.92166
#
# --- Model 4 (70% Recent) ---
# [0]	validation_0-rmse:1.01631
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98880
# [400]	validation_0-rmse:0.97281
# [600]	validation_0-rmse:0.96116
# [800]	validation_0-rmse:0.95245
# [1000]	validation_0-rmse:0.94482
# [1200]	validation_0-rmse:0.93814
# [1400]	validation_0-rmse:0.93273
# [1600]	validation_0-rmse:0.92846
# [1666]	validation_0-rmse:0.92734
#
# --- Model 5 (60% Recent) ---
# [0]	validation_0-rmse:1.01635
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98937
# [400]	validation_0-rmse:0.97476
# [600]	validation_0-rmse:0.96443
# [800]	validation_0-rmse:0.95654
# [1000]	validation_0-rmse:0.95013
# [1200]	validation_0-rmse:0.94448
# [1400]	validation_0-rmse:0.94017
# [1600]	validation_0-rmse:0.93630
# [1666]	validation_0-rmse:0.93527
#
# --- Model 6 (50% Recent) ---
# [0]	validation_0-rmse:1.01690
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99338
# [400]	validation_0-rmse:0.98012
# [600]	validation_0-rmse:0.97116
# [800]	validation_0-rmse:0.96442
# [1000]	validation_0-rmse:0.95866
# [1200]	validation_0-rmse:0.95416
# [1400]	validation_0-rmse:0.95103
# [1600]	validation_0-rmse:0.94783
# [1666]	validation_0-rmse:0.94691
#
# --- Model 7 (40% Recent) ---
# [0]	validation_0-rmse:1.01742
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99482
# [400]	validation_0-rmse:0.98397
# [600]	validation_0-rmse:0.97640
# [800]	validation_0-rmse:0.97128
# [1000]	validation_0-rmse:0.96745
# [1200]	validation_0-rmse:0.96434
# [1400]	validation_0-rmse:0.96160
# [1600]	validation_0-rmse:0.96002
# [1666]	validation_0-rmse:0.95941
#
# ##################################################
# ### Fold 2
# ##################################################
#
# --- Model 1 (100% Full Data) ---
# [0]	validation_0-rmse:1.01399
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98464
# [400]	validation_0-rmse:0.96714
# [600]	validation_0-rmse:0.95286
# [800]	validation_0-rmse:0.94167
# [1000]	validation_0-rmse:0.93229
# [1200]	validation_0-rmse:0.92373
# [1400]	validation_0-rmse:0.91606
# [1600]	validation_0-rmse:0.90967
# [1666]	validation_0-rmse:0.90781
#
# --- Model 2 (90% Recent) ---
# [0]	validation_0-rmse:1.01408
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98574
# [400]	validation_0-rmse:0.96893
# [600]	validation_0-rmse:0.95569
# [800]	validation_0-rmse:0.94556
# [1000]	validation_0-rmse:0.93625
# [1200]	validation_0-rmse:0.92881
# [1400]	validation_0-rmse:0.92154
# [1600]	validation_0-rmse:0.91519
# [1666]	validation_0-rmse:0.91336
#
# --- Model 3 (80% Recent) ---
# [0]	validation_0-rmse:1.01409
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98676
# [400]	validation_0-rmse:0.97021
# [600]	validation_0-rmse:0.95760
# [800]	validation_0-rmse:0.94717
# [1000]	validation_0-rmse:0.93917
# [1200]	validation_0-rmse:0.93256
# [1400]	validation_0-rmse:0.92640
# [1600]	validation_0-rmse:0.92073
# [1666]	validation_0-rmse:0.91900
#
# --- Model 4 (70% Recent) ---
# [0]	validation_0-rmse:1.01412
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98673
# [400]	validation_0-rmse:0.97069
# [600]	validation_0-rmse:0.95911
# [800]	validation_0-rmse:0.94967
# [1000]	validation_0-rmse:0.94228
# [1200]	validation_0-rmse:0.93623
# [1400]	validation_0-rmse:0.93092
# [1600]	validation_0-rmse:0.92601
# [1666]	validation_0-rmse:0.92457
#
# --- Model 5 (60% Recent) ---
# [0]	validation_0-rmse:1.01414
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98803
# [400]	validation_0-rmse:0.97263
# [600]	validation_0-rmse:0.96149
# [800]	validation_0-rmse:0.95353
# [1000]	validation_0-rmse:0.94751
# [1200]	validation_0-rmse:0.94214
# [1400]	validation_0-rmse:0.93754
# [1600]	validation_0-rmse:0.93358
# [1666]	validation_0-rmse:0.93233
#
# --- Model 6 (50% Recent) ---
# [0]	validation_0-rmse:1.01455
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99163
# [400]	validation_0-rmse:0.97864
# [600]	validation_0-rmse:0.96980
# [800]	validation_0-rmse:0.96269
# [1000]	validation_0-rmse:0.95707
# [1200]	validation_0-rmse:0.95231
# [1400]	validation_0-rmse:0.94867
# [1600]	validation_0-rmse:0.94594
# [1666]	validation_0-rmse:0.94523
#
# --- Model 7 (40% Recent) ---
# [0]	validation_0-rmse:1.01507
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99298
# [400]	validation_0-rmse:0.98199
# [600]	validation_0-rmse:0.97468
# [800]	validation_0-rmse:0.96968
# [1000]	validation_0-rmse:0.96602
# [1200]	validation_0-rmse:0.96365
# [1400]	validation_0-rmse:0.96103
# [1600]	validation_0-rmse:0.95931
# [1666]	validation_0-rmse:0.95871
#
# ##################################################
# ### Fold 3
# ##################################################
#
# --- Model 1 (100% Full Data) ---
# [0]	validation_0-rmse:1.00222
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97347
# [400]	validation_0-rmse:0.95589
# [600]	validation_0-rmse:0.94300
# [800]	validation_0-rmse:0.93247
# [1000]	validation_0-rmse:0.92326
# [1200]	validation_0-rmse:0.91546
# [1400]	validation_0-rmse:0.90808
# [1600]	validation_0-rmse:0.90143
# [1666]	validation_0-rmse:0.89915
#
# --- Model 2 (90% Recent) ---
# [0]	validation_0-rmse:1.00222
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97466
# [400]	validation_0-rmse:0.95754
# [600]	validation_0-rmse:0.94514
# [800]	validation_0-rmse:0.93498
# [1000]	validation_0-rmse:0.92560
# [1200]	validation_0-rmse:0.91786
# [1400]	validation_0-rmse:0.91183
# [1600]	validation_0-rmse:0.90572
# [1666]	validation_0-rmse:0.90380
#
# --- Model 3 (80% Recent) ---
# [0]	validation_0-rmse:1.00229
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97568
# [400]	validation_0-rmse:0.95887
# [600]	validation_0-rmse:0.94651
# [800]	validation_0-rmse:0.93729
# [1000]	validation_0-rmse:0.92900
# [1200]	validation_0-rmse:0.92187
# [1400]	validation_0-rmse:0.91613
# [1600]	validation_0-rmse:0.91104
# [1666]	validation_0-rmse:0.90944
#
# --- Model 4 (70% Recent) ---
# [0]	validation_0-rmse:1.00238
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97603
# [400]	validation_0-rmse:0.95984
# [600]	validation_0-rmse:0.94833
# [800]	validation_0-rmse:0.93969
# [1000]	validation_0-rmse:0.93243
# [1200]	validation_0-rmse:0.92593
# [1400]	validation_0-rmse:0.92088
# [1600]	validation_0-rmse:0.91632
# [1666]	validation_0-rmse:0.91495
#
# --- Model 5 (60% Recent) ---
# [0]	validation_0-rmse:1.00241
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97661
# [400]	validation_0-rmse:0.96181
# [600]	validation_0-rmse:0.95127
# [800]	validation_0-rmse:0.94301
# [1000]	validation_0-rmse:0.93639
# [1200]	validation_0-rmse:0.93105
# [1400]	validation_0-rmse:0.92698
# [1600]	validation_0-rmse:0.92312
# [1666]	validation_0-rmse:0.92203
#
# --- Model 6 (50% Recent) ---
# [0]	validation_0-rmse:1.00304
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98008
# [400]	validation_0-rmse:0.96723
# [600]	validation_0-rmse:0.95827
# [800]	validation_0-rmse:0.95189
# [1000]	validation_0-rmse:0.94647
# [1200]	validation_0-rmse:0.94217
# [1400]	validation_0-rmse:0.93862
# [1600]	validation_0-rmse:0.93588
# [1666]	validation_0-rmse:0.93493
#
# --- Model 7 (40% Recent) ---
# [0]	validation_0-rmse:1.00346
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98163
# [400]	validation_0-rmse:0.97031
# [600]	validation_0-rmse:0.96259
# [800]	validation_0-rmse:0.95785
# [1000]	validation_0-rmse:0.95407
# [1200]	validation_0-rmse:0.95095
# [1400]	validation_0-rmse:0.94872
# [1600]	validation_0-rmse:0.94735
# [1666]	validation_0-rmse:0.94668
#
# ##################################################
# ### Fold 4
# ##################################################
#
# --- Model 1 (100% Full Data) ---
# [0]	validation_0-rmse:1.01682
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98764
# [400]	validation_0-rmse:0.96873
# [600]	validation_0-rmse:0.95514
# [800]	validation_0-rmse:0.94418
# [1000]	validation_0-rmse:0.93430
# [1200]	validation_0-rmse:0.92632
# [1400]	validation_0-rmse:0.91856
# [1600]	validation_0-rmse:0.91228
# [1666]	validation_0-rmse:0.91008
#
# --- Model 2 (90% Recent) ---
# [0]	validation_0-rmse:1.01687
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98783
# [400]	validation_0-rmse:0.97065
# [600]	validation_0-rmse:0.95805
# [800]	validation_0-rmse:0.94708
# [1000]	validation_0-rmse:0.93810
# [1200]	validation_0-rmse:0.93001
# [1400]	validation_0-rmse:0.92371
# [1600]	validation_0-rmse:0.91783
# [1666]	validation_0-rmse:0.91606
#
# --- Model 3 (80% Recent) ---
# [0]	validation_0-rmse:1.01689
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98952
# [400]	validation_0-rmse:0.97308
# [600]	validation_0-rmse:0.96036
# [800]	validation_0-rmse:0.95067
# [1000]	validation_0-rmse:0.94248
# [1200]	validation_0-rmse:0.93516
# [1400]	validation_0-rmse:0.92947
# [1600]	validation_0-rmse:0.92411
# [1666]	validation_0-rmse:0.92264
#
# --- Model 4 (70% Recent) ---
# [0]	validation_0-rmse:1.01692
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.98994
# [400]	validation_0-rmse:0.97395
# [600]	validation_0-rmse:0.96237
# [800]	validation_0-rmse:0.95265
# [1000]	validation_0-rmse:0.94530
# [1200]	validation_0-rmse:0.93914
# [1400]	validation_0-rmse:0.93381
# [1600]	validation_0-rmse:0.92948
# [1666]	validation_0-rmse:0.92791
#
# --- Model 5 (60% Recent) ---
# [0]	validation_0-rmse:1.01694
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99017
# [400]	validation_0-rmse:0.97497
# [600]	validation_0-rmse:0.96397
# [800]	validation_0-rmse:0.95665
# [1000]	validation_0-rmse:0.94997
# [1200]	validation_0-rmse:0.94455
# [1400]	validation_0-rmse:0.94001
# [1600]	validation_0-rmse:0.93619
# [1666]	validation_0-rmse:0.93509
#
# --- Model 6 (50% Recent) ---
# [0]	validation_0-rmse:1.01739
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99424
# [400]	validation_0-rmse:0.98144
# [600]	validation_0-rmse:0.97286
# [800]	validation_0-rmse:0.96586
# [1000]	validation_0-rmse:0.96064
# [1200]	validation_0-rmse:0.95676
# [1400]	validation_0-rmse:0.95316
# [1600]	validation_0-rmse:0.95027
# [1666]	validation_0-rmse:0.94950
#
# --- Model 7 (40% Recent) ---
# [0]	validation_0-rmse:1.01775
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.99550
# [400]	validation_0-rmse:0.98422
# [600]	validation_0-rmse:0.97698
# [800]	validation_0-rmse:0.97211
# [1000]	validation_0-rmse:0.96892
# [1200]	validation_0-rmse:0.96598
# [1400]	validation_0-rmse:0.96379
# [1600]	validation_0-rmse:0.96184
# [1630]	validation_0-rmse:0.96182
#
# ##################################################
# ### Fold 5
# ##################################################
#
# --- Model 1 (100% Full Data) ---
# [0]	validation_0-rmse:0.99898
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.96952
# [400]	validation_0-rmse:0.95168
# [600]	validation_0-rmse:0.93811
# [800]	validation_0-rmse:0.92715
# [1000]	validation_0-rmse:0.91785
# [1200]	validation_0-rmse:0.90970
# [1400]	validation_0-rmse:0.90250
# [1600]	validation_0-rmse:0.89584
# [1666]	validation_0-rmse:0.89387
#
# --- Model 2 (90% Recent) ---
# [0]	validation_0-rmse:0.99902
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97084
# [400]	validation_0-rmse:0.95354
# [600]	validation_0-rmse:0.94050
# [800]	validation_0-rmse:0.92990
# [1000]	validation_0-rmse:0.92113
# [1200]	validation_0-rmse:0.91382
# [1400]	validation_0-rmse:0.90737
# [1600]	validation_0-rmse:0.90143
# [1666]	validation_0-rmse:0.89967
#
# --- Model 3 (80% Recent) ---
# [0]	validation_0-rmse:0.99909
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97187
# [400]	validation_0-rmse:0.95507
# [600]	validation_0-rmse:0.94307
# [800]	validation_0-rmse:0.93324
# [1000]	validation_0-rmse:0.92524
# [1200]	validation_0-rmse:0.91837
# [1400]	validation_0-rmse:0.91264
# [1600]	validation_0-rmse:0.90752
# [1666]	validation_0-rmse:0.90582
#
# --- Model 4 (70% Recent) ---
# [0]	validation_0-rmse:0.99911
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97156
# [400]	validation_0-rmse:0.95548
# [600]	validation_0-rmse:0.94436
# [800]	validation_0-rmse:0.93495
# [1000]	validation_0-rmse:0.92728
# [1200]	validation_0-rmse:0.92108
# [1400]	validation_0-rmse:0.91581
# [1600]	validation_0-rmse:0.91179
# [1666]	validation_0-rmse:0.91037
#
# --- Model 5 (60% Recent) ---
# [0]	validation_0-rmse:0.99913
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97268
# [400]	validation_0-rmse:0.95799
# [600]	validation_0-rmse:0.94759
# [800]	validation_0-rmse:0.93980
# [1000]	validation_0-rmse:0.93408
# [1200]	validation_0-rmse:0.92867
# [1400]	validation_0-rmse:0.92442
# [1600]	validation_0-rmse:0.92077
# [1666]	validation_0-rmse:0.91997
#
# --- Model 6 (50% Recent) ---
# [0]	validation_0-rmse:0.99958
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97668
# [400]	validation_0-rmse:0.96399
# [600]	validation_0-rmse:0.95492
# [800]	validation_0-rmse:0.94882
# [1000]	validation_0-rmse:0.94371
# [1200]	validation_0-rmse:0.93912
# [1400]	validation_0-rmse:0.93592
# [1600]	validation_0-rmse:0.93294
# [1666]	validation_0-rmse:0.93204
#
# --- Model 7 (40% Recent) ---
# [0]	validation_0-rmse:1.00001
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [200]	validation_0-rmse:0.97846
# [400]	validation_0-rmse:0.96811
# [600]	validation_0-rmse:0.96090
# [800]	validation_0-rmse:0.95594
# [1000]	validation_0-rmse:0.95259
# [1200]	validation_0-rmse:0.94954
# [1400]	validation_0-rmse:0.94745
# [1600]	validation_0-rmse:0.94529
# [1666]	validation_0-rmse:0.94490
#
# ==================================================
# INDIVIDUAL MODEL PERFORMANCE
# ==================================================
# Model 1 (100% Full Data) Pearson Correlation: 0.5018
# Model 2 (90% Recent) Pearson Correlation: 0.5141
# Model 3 (80% Recent) Pearson Correlation: 0.5217
# Model 4 (70% Recent) Pearson Correlation: 0.5285
# Model 5 (60% Recent) Pearson Correlation: 0.5355
# Model 6 (50% Recent) Pearson Correlation: 0.5373
# Model 7 (40% Recent) Pearson Correlation: 0.5370
#
# ==================================================
# ENSEMBLE PERFORMANCE
# ==================================================
# Ensemble (Equal Weight) Pearson Correlation: 0.5342
#
# Weighted Ensemble Performance:
#   Model 1 (100% Full Data) weight: 0.137
#   Model 2 (90% Recent) weight: 0.140
#   Model 3 (80% Recent) weight: 0.142
#   Model 4 (70% Recent) weight: 0.144
#   Model 5 (60% Recent) weight: 0.146
#   Model 6 (50% Recent) weight: 0.146
#   Model 7 (40% Recent) weight: 0.146
#   Weighted Ensemble Pearson Correlation: 0.5345
#
# Using weighted ensemble for final predictions
#
# Generating SHAP analysis...
# [19:57:26] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
# Predictions saved to submission.csv
#    ID  prediction
# 0   1    0.177299
# 1   2   -0.017867
# 2   3    0.174881
# 3   4   -0.073545
# 4   5    0.249571
#
# Ensemble results saved to ensemble_results.csv
#                       model  pearson_correlation  weight_in_final
# 0  Model 1 (100% Full Data)             0.501826         0.136518
# 1      Model 2 (90% Recent)             0.514087         0.139853
# 2      Model 3 (80% Recent)             0.521665         0.141915
# 3      Model 4 (70% Recent)             0.528477         0.143768
# 4      Model 5 (60% Recent)             0.535533         0.145688
# 5      Model 6 (50% Recent)             0.537301         0.146168
# 6      Model 7 (40% Recent)             0.537015         0.146091
# 7           Simple Ensemble             0.534237              NaN
# 8         Weighted Ensemble             0.534536              NaN
# invalid value encountered in greater
# invalid value encountered in less
# invalid value encountered in greater
