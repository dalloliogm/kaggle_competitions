# %% [markdown]
# - 0.12744 &nbsp;v.10 - [Top Notebook + New Model CSV Ensemble](https://www.kaggle.com/code/migrantworkerdatahub/top-notebook-new-model-csv-ensemble) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12958 &nbsp;v.03 - [DRW - Ensemble of Ensemble of Ensemble](https://www.kaggle.com/code/yingjunmao/drw-ensemble-of-ensemble-of-ensemble) - [YingJunMao](https://www.kaggle.com/yingjunmao)
# - 0.12864 &nbsp;v.26 - [**5 subm.files** from page Ensemble_Envy / averaged_final_submissions -> iBlend](https://www.kaggle.com/code/taylorsamarel/ensemble-envy) - [Lion-li-li](https://)
#
# 3-july-2025 - LB = [?](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)

# %% [markdown]
# Journal
#
# &nbsp;
#
# - 0.12092 - v.01 - [DRW Competition | End-to-End Notebook](https://www.kaggle.com/code/battleninza/drw-competition-end-to-end-notebook/notebook) - [ABHAY SINGH](https://www.kaggle.com/battleninza)
# - 0.11914 - v.06 - [DRW - Crypto d75cea](https://www.kaggle.com/code/jasonzhang2022/drw-crypto-d75cea/notebook) - [jason](https://www.kaggle.com/jasonzhang2022)
# - 0.11893 - v.03 - [DRW_2](https://www.kaggle.com/code/rozzzz/drw-2/output?scriptVersionId=245591154) - [ROZZZZ](https://www.kaggle.com/rozzzz)
# - 0.11756 - v.14 - [DRW Competition Submission](https://www.kaggle.com/code/rosswade/drw-competition-submission/notebook?scriptVersionId=245352571) - [Ross Wade](https://www.kaggle.com/rosswade)
#
# 22-june-2025 - LB = [0.12206](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12252 - v.01 - [Low Signal to Noise](https://www.kaggle.com/code/taylorsamarel/low-signal-to-noise) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - 0.11914 - v.06 - [DRW - Crypto d75cea](https://www.kaggle.com/code/jasonzhang2022/drw-crypto-d75cea/notebook) - [jason](https://www.kaggle.com/jasonzhang2022)
# - 0.11893 - v.03 - [DRW_2](https://www.kaggle.com/code/rozzzz/drw-2/output?scriptVersionId=245591154) - [ROZZZZ](https://www.kaggle.com/rozzzz)
# - 0.11756 - v.14 - [DRW Competition Submission](https://www.kaggle.com/code/rosswade/drw-competition-submission/notebook?scriptVersionId=245352571) - [Ross Wade](https://www.kaggle.com/rosswade)
#
#
# 23-june-2025 - LB = [0.12327](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12307 - v.02 - [DRW Remix VI + Fourth Time Slice](https://www.kaggle.com/code/migrantworkerdatahub/drw-remix-vi-fourth-time-slice) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12280 - v.06 - [DRW Remix VI](https://www.kaggle.com/code/bakuer30/drw-remix-vi) - [Bakuer30](https://www.kaggle.com/bakuer30)
# - 0.12252 - v.01 - [Low Signal to Noise](https://www.kaggle.com/code/taylorsamarel/low-signal-to-noise) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - 0.12154 - v.24 - [DRW Competition Submission](https://www.kaggle.com/code/rosswade/drw-competition-submission) - [Ross Wade](https://www.kaggle.com/rosswade)
#
# 27-june-2025 - LB = [0.12407](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12419 - v.03 - [CPU Based DRW VI - Fourth Time Slice Remixed](https://www.kaggle.com/code/migrantworkerdatahub/drw-remix-vi-fourth-time-slice) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12307 - v.02 - [DRW Remix VI + Fourth Time Slice](https://www.kaggle.com/code/migrantworkerdatahub/drw-remix-vi-fourth-time-slice) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12280 - v.06 - [DRW Remix VI](https://www.kaggle.com/code/bakuer30/drw-remix-vi) - [Bakuer30](https://www.kaggle.com/bakuer30)
# - 0.12252 - v.01 - [Low Signal to Noise](https://www.kaggle.com/code/taylorsamarel/low-signal-to-noise) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
#
# 29-june-2025 - LB = [0.12483](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
#
# - 0.12541 - v.01 - [DRW - XGB Train Data Recency](https://www.kaggle.com/code/shinchen93/drw-xgb-train-data-recency/notebook) - [ShinC](https://www.kaggle.com/shinchen93)
# - 0.12419 - v.03 - [CPU Based DRW VI - Fourth Time Slice Remixed](https://www.kaggle.com/code/migrantworkerdatahub/drw-remix-vi-fourth-time-slice) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12307 - v.02 - [DRW Remix VI + Fourth Time Slice](https://www.kaggle.com/code/migrantworkerdatahub/drw-remix-vi-fourth-time-slice) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12280 - v.06 - [DRW Remix VI](https://www.kaggle.com/code/bakuer30/drw-remix-vi) - [Bakuer30](https://www.kaggle.com/bakuer30)
#
# 30-june-2025 - LB = [0.12549](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12669 v.03 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12591 v.02 - [Sub-Sample Vs. Super-Sample Noisy Rows](https://www.kaggle.com/code/taylorsamarel/sub-sample-vs-super-sample-noisy-rows) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - 0.12578 v.03 - [ITS SO COMPLICATED](https://www.kaggle.com/code/taylorsamarel/its-so-complicated) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - 0.12574 v.01 - [New Ensemble](https://www.kaggle.com/code/taylorsamarel/new-ensemble) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - 0.12574 v.01 - [XGB + Deep Learning Ensemble](https://www.kaggle.com/code/taylorsamarel/xgb-deep-learning-ensemble) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
#
# 1-july-2025 - LB = [0.12669](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12673_e1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_x1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673 &nbsp; &nbsp;&nbsp; v.**04** - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12673_x2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_e2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
#
# 2-july-2025 - LB = [0.12676](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12673_e1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_x1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12774 &nbsp; &nbsp;&nbsp; v.**10** - [Top Notebook + New Model CSV Ensemble](https://www.kaggle.com/code/migrantworkerdatahub/top-notebook-new-model-csv-ensemble) &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12673 &nbsp; &nbsp;&nbsp; v.**04** - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12673_x2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_e2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
#
#
# 2-july-2025 - LB = [0.12743](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12673_e1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_x1 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12744 &nbsp; &nbsp;&nbsp; v.**10** - [Top Notebook + New Model CSV Ensemble](https://www.kaggle.com/code/migrantworkerdatahub/top-notebook-new-model-csv-ensemble) &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12673_x2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
# - 0.12673_e2 v.04 - [XGB + Deep Learning - Updated Ensemble Weights](https://www.kaggle.com/code/migrantworkerdatahub/xgb-deep-learning-updated-ensemble-weights)
#
#
# 2-july-2025 - LB = [postponed](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;
#
# - 0.12744 &nbsp;v.10 - [Top Notebook + New Model CSV Ensemble](https://www.kaggle.com/code/migrantworkerdatahub/top-notebook-new-model-csv-ensemble) - [Migrant Worker Data Hub](https://www.kaggle.com/migrantworkerdatahub)
# - 0.12947 &nbsp;v.01 - [**Ensemble Envy**](https://www.kaggle.com/code/taylorsamarel/ensemble-envy) - [Taylor S. Amarel](https://www.kaggle.com/taylorsamarel)
# - **5 subm.files** from page Ensemble_Envy / averaged_final_submissions -> iBlend -> Lb=0.12_864
#
#
# 3-july-2025 - LB = [postponed](https://www.kaggle.com/code/nina2025/drw-crypto-market-prediction-iblend)
#
# &nbsp;

# %%
import pandas as pd

# %%
path_to_ds ='/kaggle/input/3-july-2025-drw/submission__'

file_short_names = ['0.12_744','0.12_864','0.12_958']

# %%
def iBlend(path_to_ds, file_short_names, sls):

    def tida(sls):
        
        def read_subm(sls,i):
            tnm = sls["subm"][i]["name"]
            FiN = sls["path"] + tnm + ".csv"
            return pd.read_csv(FiN).rename(columns={'target':tnm, sls["target"]:tnm})
        
        dfs_subm = [read_subm(sls,i) for i in range(len(sls["subm"]))]
        df_subms = pd.merge(dfs_subm[0],  dfs_subm[1], on=['ID'])
        
        for i in range(2, len(sls["subm"])): 
            df_subms = pd.merge(df_subms, dfs_subm[i], on=['ID'])
            
        cols = [col for col in df_subms.columns if col != "ID"]
        short_name_cols = [c.replace(sls["prefix"], '') for c in cols]
        corrects = [wt for wt in sls["subwts"]]
        weights = [subm['weight'] for subm in sls["subm"]]
        
        def alls(x, cs=cols):
            tes = {c: x[c] for c in cs}.items()
            subms_sorted = [
              t[0].replace(sls["prefix"], '')
              for t in sorted(tes,key=lambda k:k[1],reverse=True if sls["sort"]=='desc' else False)]
            return subms_sorted
        
        def correct(x, cs=cols, w=weights, cw=corrects):
            ic = [x['alls'].index(c) for c in short_name_cols]
            cS = [x[cols[j]] * (w[j] + cw[ic[j]]) for j in range(len(cols))]
            return sum(cS)
        
        df_subms['alls']        = df_subms.apply(lambda x: alls   (x), axis=1)
        df_subms[sls["target"]] = df_subms.apply(lambda x: correct(x), axis=1)
        
        schema_rename = { old_nc:new_shnc for old_nc, new_shnc in zip(cols, short_name_cols) }
        
        df_subms = df_subms.rename(columns=schema_rename)
        df_subms = df_subms.rename(columns={sls["target"]:"ensemble"})
        
        df_subms.insert(loc=1, column=' _ ', value=['   '] * sls["q_rows"])
        
        df_subms[' _ '] = df_subms[' _ '].astype(str)
        pd.set_option('display.max_rows',100)
        pd.set_option('display.float_format', '{:.4f}'.format)
        vcols = ['ID'] + [' _ '] + short_name_cols + [' _ '] + ['alls'] + [' _ '] + ['ensemble']
        df_subms = df_subms[vcols]
        display(df_subms.head(4))
        pd.set_option('display.float_format', '{:.7f}'.format)
        df_subms = df_subms.rename(columns={"ensemble":sls["target"]})
        
        return df_subms
        

    sample_subm = pd.read_csv(path_to_ds + file_short_names[1] + ".csv")

    
    def ensemble_tida(sls,submission=sample_subm):   
        sls['sort'] = 'desc'
        dfs = tida(sls)
        dfD = dfs[['ID', sls['target']]]
        dfD.to_csv(f'tida_desc.csv', index=False)
        sls['sort'] = 'asc'
        dfs = tida(sls)
        dfA = dfs[['ID', sls['target']]]
        dfA.to_csv(f'tida_asc.csv',  index=False)
        target,d,a = sls['target'],sls['desc'],sls['asc']
        submission[target] = dfD[target] * d + a * dfA[target]
        return submission

    submission = ensemble_tida(sls)
    
    return submission

# %%
params = {
      'path'  : path_to_ds,                                 
      'sort'  : "dynamic",
      'target': "prediction",
      'q_rows': 538_150,
      'prefix': "subm_",
      'desc'  : 0.50,
      'asc'   : 0.50,
      'subwts': [+0.03, -0.01, -0.02],              # LB = 0.12_955
      'subm'  : [
        { 'name':file_short_names[0],'weight':0.02, },
        { 'name':file_short_names[1],'weight':0.03, },
        { 'name':file_short_names[2],'weight':0.95, },
      ]
    }

params = {
      'path'  : path_to_ds,                                 
      'sort'  : "dynamic",
      'target': "prediction",
      'q_rows': 538_150,
      'prefix': "subm_",
      'desc'  : 0.50,
      'asc'   : 0.50,
      'subwts': [0, -0.003, +0.003],                 # LB = 0.12_957
      'subm'  : [
        { 'name':file_short_names[0],'weight':0.003, },
        { 'name':file_short_names[1],'weight':0.007, },
        { 'name':file_short_names[2],'weight':0.99,  },
      ]
    }

params = {
      'path'  : path_to_ds,                                 
      'sort'  : "dynamic",
      'target': "prediction",
      'q_rows': 538_150,
      'prefix': "subm_",
      'desc'  : 0.70,
      'asc'   : 0.30,
      'subwts': [0, -0.003, +0.003],                 # LB = 
      'subm'  : [
        { 'name':file_short_names[0],'weight':0.002, },
        { 'name':file_short_names[1],'weight':0.007, },
        { 'name':file_short_names[2],'weight':0.99,  },
      ]
    }

# %%
df = iBlend ( path_to_ds, file_short_names, params )

df.to_csv('submission.csv', index=False)

display(df)
# Out:
#    ID   _   0.12_744  0.12_864  0.12_958   _                             alls  \
# 0   1         0.0975    0.0356    0.0818       [0.12_744, 0.12_958, 0.12_864]
# 1   2         0.0103   -0.0423   -0.0795       [0.12_744, 0.12_864, 0.12_958]
# 2   3         0.1722    0.2249    0.4282       [0.12_958, 0.12_864, 0.12_744]
# 3   4        -0.0467   -0.0661   -0.0685       [0.12_744, 0.12_864, 0.12_958]
#
#     _   ensemble
# 0         0.0813
# 1        -0.0791
# 2         0.4256
# 3        -0.0684
#    ID   _   0.12_744  0.12_864  0.12_958   _                             alls  \
# 0   1         0.0975    0.0356    0.0818       [0.12_864, 0.12_958, 0.12_744]
# 1   2         0.0103   -0.0423   -0.0795       [0.12_958, 0.12_864, 0.12_744]
# 2   3         0.1722    0.2249    0.4282       [0.12_744, 0.12_864, 0.12_958]
# 3   4        -0.0467   -0.0661   -0.0685       [0.12_958, 0.12_864, 0.12_744]
#
#     _   ensemble
# 0         0.0815
# 1        -0.0788
# 2         0.4264
# 3        -0.0683
# ...

# %%
# archive launches


# redirrect

# path = '/kaggle/input/ensemble-envy/averaged_final_submissions/'

# r = pd.read_csv(path + 'ensemble_xgb_mlp30_xgb_gandalf70.csv'); r.to_csv("Envy_1.csv",index=False)
# r = pd.read_csv(path + 'ensemble_xgb_mlp40_xgb_gandalf60.csv'); r.to_csv("Envy_2.csv",index=False)
# r = pd.read_csv(path + 'ensemble_xgb_mlp50_xgb_gandalf50.csv'); r.to_csv("Envy_3.csv",index=False)
# r = pd.read_csv(path + 'ensemble_xgb_mlp60_xgb_gandalf40.csv'); r.to_csv("Envy_4.csv",index=False)
# r = pd.read_csv(path + 'ensemble_xgb_mlp70_xgb_gandalf30.csv'); r.to_csv("Envy_5.csv",index=False)

# path = '/kaggle/input/2-july-2025-drw/'

# r = pd.read_csv(path + 'submission__0.12_774.csv'); r.to_csv("0.12_744.csv",index=False)

# path__Envy_subms ='/kaggle/working/'

# file_short_names = ['Envy_1','Envy_2','Envy_3','Envy_4','Envy_5']

#================================================================================
#====================================postponed===================================

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.70,
#       'asc'   : 0.30,
#       'subwts': [+0.02, +0.01, -0.005, -0.010, -0.015],     # LB = 0.12_743 
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.01, },
#         { 'name':file_short_names[1],'weight':0.005, },
#         { 'name':file_short_names[2],'weight':0.97, },
#         { 'name':file_short_names[3],'weight':0.005, },
#         { 'name':file_short_names[4],'weight':0.01, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.02, +0.01, -0.005, -0.010, -0.015],     # LB = ?
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.01, },
#         { 'name':file_short_names[1],'weight':0.005, },
#         { 'name':file_short_names[2],'weight':0.97, },
#         { 'name':file_short_names[3],'weight':0.005, },
#         { 'name':file_short_names[4],'weight':0.01, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.30,
#       'asc'   : 0.70,
#       'subwts': [+0.02, +0.01, -0.005, -0.010, -0.015],     # LB = ?
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.01, },
#         { 'name':file_short_names[1],'weight':0.005, },
#         { 'name':file_short_names[2],'weight':0.97, },
#         { 'name':file_short_names[3],'weight':0.005, },
#         { 'name':file_short_names[4],'weight':0.01, },
#       ]
#     }

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.55,
#       'asc'   : 0.45,
#       'subwts': [+0.002, +0.001, 0, -0.001, -0.002],     # LB = ?
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.0021, },
#         { 'name':file_short_names[1],'weight':0.0054, },
#         { 'name':file_short_names[2],'weight':0.985, },
#         { 'name':file_short_names[3],'weight':0.0054, },
#         { 'name':file_short_names[4],'weight':0.0021, },
#       ]
#     }
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.002, +0.001, 0, -0.001, -0.002],     # LB = ?
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.0021, },
#         { 'name':file_short_names[1],'weight':0.0054, },
#         { 'name':file_short_names[2],'weight':0.985, },
#         { 'name':file_short_names[3],'weight':0.0054, },
#         { 'name':file_short_names[4],'weight':0.0021, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.45,
#       'asc'   : 0.55,
#       'subwts': [+0.002, +0.001, 0, -0.001, -0.002],     # LB = ?
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.0021, },
#         { 'name':file_short_names[1],'weight':0.0054, },
#         { 'name':file_short_names[2],'weight':0.985, },
#         { 'name':file_short_names[3],'weight':0.0054, },
#         { 'name':file_short_names[4],'weight':0.0021, },
#       ]
#     }


#====================================postponed===================================
#================================================================================


# path_to_ds ='/kaggle/input/2-july-2025-drw/submission__'

# file_short_names = ['0.12_673_e1','0.12_673_x1','0.12_774','0.12_673','0.12_673_x2','0.12_673_e2' ]

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.05, +0.03, 0, -0.01, -0.03, -0.04],      # LB = 0.12_739
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.03, },
#         { 'name':file_short_names[1],'weight':0.02, },
#         { 'name':file_short_names[2],'weight':0.95, },
#         { 'name':file_short_names[3],'weight':0.05, },
#         { 'name':file_short_names[4],'weight':0.02, },
#         { 'name':file_short_names[5],'weight':0.03, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.020, +0.010, -0.005, -0.005, -0.010, -0.010],      # LB = 0.12_743
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.01, },
#         { 'name':file_short_names[1],'weight':0.01, },
#         { 'name':file_short_names[2],'weight':0.95, },
#         { 'name':file_short_names[3],'weight':0.01, },
#         { 'name':file_short_names[4],'weight':0.01, },
#         { 'name':file_short_names[5],'weight':0.01, },
#       ]
#     }


# path_to_ds ='/kaggle/input/2-july-2025-drw/submission__'

# file_short_names = ['0.12_673_e1','0.12_673_x1','0.12_673','0.12_673_x2','0.12_673_e2' ]

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.05, +0.03, -0.01, -0.03, -0.04],      # LB = 0.12_675
#       'subm'  : [
#         { 'name':file_short_names[0],'weight':0.02, },
#         { 'name':file_short_names[1],'weight':0.01, },
#         { 'name':file_short_names[2],'weight':0.95, },
#         { 'name':file_short_names[3],'weight':0.01, },
#         { 'name':file_short_names[4],'weight':0.02, },
#       ]
#     }


# path_to_ds ='/kaggle/input/1-juli-2025-drw-public-submission' + '/submission__'

# file_short_names = ['0.12_669','0.12_591','0.12_578','0.12_5742','0.12_5741' ]

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.20,+10, 0, -0.10,-0.20],              LB = 0.12_606
#       'subm'  : [
#         { 'name':'0.12_669', 'weight':0.20, },
#         { 'name':'0.12_591', 'weight':0.20, },
#         { 'name':'0.12_578', 'weight':0.20, },
#         { 'name':'0.12_5742','weight':0.20, },
#         { 'name':'0.12_5741','weight':0.20, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.15,+0.07, 0, -0.07,-0.15],            LB = 0.12_615
#       'subm'  : [
#         { 'name':'0.12_669', 'weight':0.20, },
#         { 'name':'0.12_591', 'weight':0.20, },
#         { 'name':'0.12_578', 'weight':0.20, },
#         { 'name':'0.12_5742','weight':0.20, },
#         { 'name':'0.12_5741','weight':0.20, },
#       ]
#     }

# params = {                                       
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [-0.12, +0.07, +0.10, +0.07, -0.12],      LB = 0.12_590
#       'subm'  : [
#         { 'name':'0.12_669', 'weight':0.30, },
#         { 'name':'0.12_591', 'weight':0.23, },
#         { 'name':'0.12_578', 'weight':0.19, },
#         { 'name':'0.12_5742','weight':0.14, },
#         { 'name':'0.12_5741','weight':0.14, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.05, +0.03, -0.01, -0.03, -0.04],      LB = 0.12_662
#       'subm'  : [
#         { 'name':'0.12_669', 'weight':0.80, },
#         { 'name':'0.12_591', 'weight':0.07, },
#         { 'name':'0.12_578', 'weight':0.05, },
#         { 'name':'0.12_5742','weight':0.04, },
#         { 'name':'0.12_5741','weight':0.04, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.05, +0.03, -0.01, -0.03, -0.04],      LB= 0.12_669
#       'subm'  : [
#         { 'name':'0.12_673', 'weight':0.95, },
#         { 'name':'0.12_591', 'weight':0.02, },
#         { 'name':'0.12_578', 'weight':0.01, },
#         { 'name':'0.12_5742','weight':0.01, },
#         { 'name':'0.12_5741','weight':0.01, },
#       ]
#     }

# params = {
#       'path'  : path_to_ds,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'desc'  : 0.50,
#       'asc'   : 0.50,
#       'subwts': [+0.05, +0.03, -0.01, -0.03, -0.04],      LB= 0.12_669
#       'subm'  : [
#         { 'name':'0.12_673', 'weight':0.95, },
#         { 'name':'0.12_591', 'weight':0.02, },
#         { 'name':'0.12_578', 'weight':0.01, },
#         { 'name':'0.12_5742','weight':0.01, },
#         { 'name':'0.12_5741','weight':0.01, },
#       ]
#     }

# %%
# archive

# Proven working version

# def _Tida(path, file_short_names):
    
#     path += '/submission__'

#     import pandas as pd

#     def tida(sls):
        
#         def read_subm(sls,i):
#             tnm = sls["subm"][i]["name"]
#             FiN = sls["path"] + tnm + ".csv"
#             return pd.read_csv(FiN).rename(columns={'target':tnm, sls["target"]:tnm})
        
#         dfs_subm = [read_subm(sls,i) for i in range(len(sls["subm"]))]
#         df_subms = pd.merge(dfs_subm[0],  dfs_subm[1], on=['ID'])
        
#         for i in range(2, len(sls["subm"])): 
#             df_subms = pd.merge(df_subms, dfs_subm[i], on=['ID'])
            
#         cols = [col for col in df_subms.columns if col != "ID"]
#         short_name_cols = [c.replace(sls["prefix"], '') for c in cols]
#         corrects = [wt for wt in sls["subwts"]]
#         weights = [subm['weight'] for subm in sls["subm"]]
        
#         def alls(x, cs=cols):
#             tes = {c: x[c] for c in cs}.items()
#             subms_sorted = [
#               t[0].replace(sls["prefix"], '')
#               for t in sorted(tes,key=lambda k:k[1],reverse=True if sls["sort"]=='desc' else False)]
#             return subms_sorted
        
#         def correct(x, cs=cols, w=weights, cw=corrects):
#             ic = [x['alls'].index(c) for c in short_name_cols]
#             cS = [x[cols[j]] * (w[j] + cw[ic[j]]) for j in range(len(cols))]
#             return sum(cS)
        
#         df_subms['alls']        = df_subms.apply(lambda x: alls   (x), axis=1)
#         df_subms[sls["target"]] = df_subms.apply(lambda x: correct(x), axis=1)
        
#         schema_rename = { old_nc:new_shnc for old_nc, new_shnc in zip(cols, short_name_cols) }
        
#         df_subms = df_subms.rename(columns=schema_rename)
#         df_subms = df_subms.rename(columns={sls["target"]:"ensemble"})
        
#         df_subms.insert(loc=1, column=' _ ', value=['   '] * sls["q_rows"])
        
#         df_subms[' _ '] = df_subms[' _ '].astype(str)
#         pd.set_option('display.max_rows',100)
#         pd.set_option('display.float_format', '{:.3f}'.format)
#         vcols = ['ID'] + [' _ '] + short_name_cols + [' _ '] + ['alls'] + [' _ '] + ['ensemble']
#         df_subms = df_subms[vcols]
#         display(df_subms.head(10))
#         pd.set_option('display.float_format', '{:.7f}'.format)
#         df_subms = df_subms.rename(columns={"ensemble":sls["target"]})
        
#         return df_subms
   
    
#     # sls.1 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.17,+0.07, -0.07, -0.17],       # 0.12_476,  desc/asc wts = 37x63
#     #   'subm'  : [
#     #     { 'name':'0.12_419', 'weight':0.70, },
#     #     { 'name':'0.12_307', 'weight':0.13, },
#     #     { 'name':'0.12_280', 'weight':0.09, },
#     #     { 'name':'0.12_252', 'weight':0.08, },
#     #   ]
#     # }

#     # sls.2 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.17,+0.07, -0.07, -0.17],       # Lb=12_482,  desc/asc wts = 37x63
#     #   'subm'  : [
#     #     { 'name':'0.12_419', 'weight':0.64, },
#     #     { 'name':'0.12_307', 'weight':0.15, },
#     #     { 'name':'0.12_280', 'weight':0.11, },
#     #     { 'name':'0.12_252', 'weight':0.10, },
#     #   ]
#     # }

#     # sls.3 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.17,+0.07, -0.07, -0.17],       # Lb=12_483,  desc/asc wts = 35x65
#     #   'subm'  : [
#     #     { 'name':'0.12_419', 'weight':0.61, },
#     #     { 'name':'0.12_307', 'weight':0.16, },
#     #     { 'name':'0.12_280', 'weight':0.12, },
#     #     { 'name':'0.12_252', 'weight':0.11, },
#     #   ]
#     # }

#     # sls.4 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.15,+0.05, -0.05, -0.15],       # Lb=0.12526,  desc/asc wts = 35x65
#     #   'subm'  : [
#     #     { 'name':'0.12_541', 'weight':0.70, },
#     #     { 'name':'0.12_419', 'weight':0.15, },
#     #     { 'name':'0.12_307', 'weight':0.08, },
#     #     { 'name':'0.12_280', 'weight':0.07, },
#     #   ]
#     # }

#     # sls.5 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.05,+0.02, -0.02, -0.05],       # Lb=0.12543,  desc/asc wts = 40x60
#     #   'subm'  : [
#     #     { 'name':'0.12_541', 'weight':0.80, },
#     #     { 'name':'0.12_419', 'weight':0.10, },
#     #     { 'name':'0.12_307', 'weight':0.05, },
#     #     { 'name':'0.12_280', 'weight':0.05, },
#     #   ]
#     # }

#     # sls.8 = {
#     #   'path'  : path,                                 
#     #   'sort'  : "dynamic",
#     #   'target': "prediction",
#     #   'q_rows': 538_150,
#     #   'prefix': "subm_",
#     #   'subwts': [+0.04,+0.03, -0.03, -0.04],        # Lb=0.12_546,  desc/asc wts = 45x55
#     #   'subm'  : [
#     #     { 'name':'0.12_541', 'weight':0.79, },
#     #     { 'name':'0.12_419', 'weight':0.13, },
#     #     { 'name':'0.12_307', 'weight':0.04, },
#     #     { 'name':'0.12_280', 'weight':0.04, },
#     #   ]
#     # }

#     sls = {
#       'path'  : path,                                 
#       'sort'  : "dynamic",
#       'target': "prediction",
#       'q_rows': 538_150,
#       'prefix': "subm_",
#       'subwts': [+0.15,-0.02, -0.05, -0.08],        # Lb=?,          desc/asc wts = 50x50
#       'subm'  : [
#         { 'name':'0.12_541', 'weight':0.74, },
#         { 'name':'0.12_419', 'weight':0.12, },
#         { 'name':'0.12_307', 'weight':0.07, },
#         { 'name':'0.12_280', 'weight':0.07, },
#       ]
#     }
    
    
#     submission = pd.read_csv(path + file_short_names[1] + ".csv")
    
#     def ensemble_tida(type_sort, weight):
#         sls['sort'] = type_sort
#         dfs = tida(sls)
#         df  = dfs[['ID', sls['target']]]
#         df.to_csv(f'tida_{type_sort}.csv', index=False)
#         return df,weight


#     # subm_D,d = ensemble_tida('desc', 0.50)  Lb=0.12_472  sls.1
#     # subm_A,a = ensemble_tida('asc' , 0.50)

#     # subm_D,d = ensemble_tida('desc', 0.45)  Lb=0.12_475  sls.1
#     # subm_A,a = ensemble_tida('asc' , 0.55)

#     # subm_D,d = ensemble_tida('desc', 0.40)  Lb=0.12_476  sls.1
#     # subm_A,a = ensemble_tida('asc' , 0.60)

#     # subm_D,d = ensemble_tida('desc', 0.37)  Lb=0.12_482  sls.2
#     # subm_A,a = ensemble_tida('asc' , 0.63)

#     # subm_D,d = ensemble_tida('desc', 0.35)  Lb=0.12_483  sls.3
#     # subm_A,a = ensemble_tida('asc' , 0.65)

#     # subm_D,d = ensemble_tida('desc', 0.35)  Lb=0.12_526  sls.4
#     # subm_A,a = ensemble_tida('asc' , 0.65)

#     # subm_D,d = ensemble_tida('desc', 0.40)  Lb=0.12_541  sls.5
#     # subm_A,a = ensemble_tida('asc' , 0.60)

#     # subm_D,d = ensemble_tida('desc', 0.45)  Lb=0.12_546  sls.8
#     # subm_A,a = ensemble_tida('asc' , 0.55)

#     subm_D,d = ensemble_tida('desc', 0.50)  #Lb=?         sls
#     subm_A,a = ensemble_tida('asc' , 0.50)
    
#     target = sls['target']

    
#     submission[target] = subm_D[target] * d + a * subm_A[target]
    
#     return submission

# XGB + Deep Learning Ensemble
# https://www.kaggle.com/code/taylorsamarel/xgb-deep-learning-ensemble/output?select=submission_ensemble.csv


# New Ensemble
# https://www.kaggle.com/code/taylorsamarel/new-ensemble


# Tuned With New Slice Of Oldest Data
# https://www.kaggle.com/code/taylorsamarel/tuned-with-new-slice-of-oldest-data/output


# DRW - XGB + NN Train Data Recency
# https://www.kaggle.com/code/qiweiyin/drw-xgb-nn-train-data-recency/output
# Yin Qiwei
# https://www.kaggle.com/qiweiyin
