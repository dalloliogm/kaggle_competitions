# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Sustainable Water Management through Irrigation Prediction | PS6E4</p>

# %% [markdown]
# ![ChatGPT Image Apr 18, 2026, 06_47_41 PM (1).png](attachment:cbb987a1-a4f3-4119-bd3b-aa708ee0de2c.png)

# %% [markdown]
# <div style="
#     padding: 32px;
#     border-radius: 30px;
#     margin: 30px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 15px 40px rgba(0,0,0,0.55);
# ">
#     <!-- HEADER -->
#     <div style="
#         text-align: center;
#         margin-bottom: 25px;
#         padding: 20px 30px;
#         border-radius: 20px;
#         background: linear-gradient(90deg, #9b1c31, #7c2d12);
#         border: 2px solid #fde68a;
#     ">
#         <h2 style="
#             margin: 0;
#             font-family: 'Georgia', serif;
#             font-size: 26px;
#             color: #fde68a;
#             letter-spacing: 2px;
#             font-weight: bold;
#             text-shadow: 0 2px 4px rgba(0,0,0,0.6);
#         ">
#             📦 Dataset Overview - Irrigation Prediction
#         </h2>
#     </div>
#     <!-- TABLE WRAPPER (IMPORTANT FIX) -->
#     <div style="
#         border-radius: 16px;
#         overflow: hidden;
#         box-shadow: 0 8px 25px rgba(0,0,0,0.4);
#     ">
#         <table style="
#             width: 100%;
#             border-collapse: collapse;
#             font-family: 'Georgia', serif;
#             background: rgba(255,255,255,0.05);
#         ">
#             <thead>
#                 <tr>
#                     <th style="
#                         padding: 18px 20px;
#                         color: #fde68a !important;
#                         font-size: 18px;
#                         text-align: center;
#                         border-bottom: 4px solid #22c55e;
#                         font-weight: bold;
#                         background: rgba(124, 45, 18, 0.95) !important;
#                     ">
#                         📁 File Name
#                     </th>
#                     <th style="
#                         padding: 18px 20px;
#                         color: #fde68a !important;
#                         font-size: 18px;
#                         text-align: center;
#                         border-bottom: 4px solid #22c55e;
#                         font-weight: bold;
#                         background: rgba(124, 45, 18, 0.95) !important;
#                     ">
#                         📝 Description
#                     </th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr style="background: rgba(251, 191, 36, 0.12);">
#                     <td style="padding: 18px 20px; text-align: center; color: #fef3c7; font-weight: bold;">
#                         train.csv
#                     </td>
#                     <td style="padding: 18px 20px; color: #ffe4b5;">
#                         Training dataset containing features and target variable <strong>Irrigation_Need</strong>.
#                     </td>
#                 </tr>
#                 <tr style="background: rgba(34, 197, 94, 0.10);">
#                     <td style="padding: 18px 20px; text-align: center; color: #fef3c7; font-weight: bold;">
#                         test.csv
#                     </td>
#                     <td style="padding: 18px 20px; color: #ffe4b5;">
#                         Test dataset used for prediction. Only features are provided; predict <strong>Irrigation_Need</strong>.
#                     </td>
#                 </tr>
#                 <tr style="background: rgba(124, 58, 237, 0.10);">
#                     <td style="padding: 18px 20px; text-align: center; color: #fef3c7; font-weight: bold;">
#                         sample_submission.csv
#                     </td>
#                     <td style="padding: 18px 20px; color: #ffe4b5;">
#                         Submission format file showing correct structure for predicted <strong>Irrigation_Need</strong>.
#                     </td>
#                 </tr>
#             </tbody>
#         </table>
#     </div>
# </div>

# %% [markdown]
# <div style="
#     padding: 34px;
#     border-radius: 30px;
#     margin: 30px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 18px 50px rgba(0,0,0,0.6);
# ">
#     <!-- HEADER -->
#     <div style="
#         text-align: center;
#         margin-bottom: 25px;
#         padding: 18px 30px;
#         border-radius: 22px;
#         background: linear-gradient(90deg, #9b1c31, #7c2d12);
#         border: 1px solid #fde68a;
#     ">
#         <h2 style="
#             margin: 0;
#             font-family: Georgia, serif;
#             font-size: 24px;
#             color: #fde68a !important;
#             letter-spacing: 1.5px;
#             font-weight: bold;
#         ">
#             👩‍💻 About Author & Notebook Overview
#         </h2>
#     </div>
#     <!-- CONTENT BOX -->
#     <div style="
#         padding: 26px;
#         border-radius: 18px;
#         background: rgba(255,255,255,0.15);
#         border: 1px solid rgba(34,197,94,0.5);
#         font-family: Georgia, serif;
#         color: #fff7d6 !important;
#         line-height: 1.9;
#         font-size: 16px;
#     ">
#         <p style="color:#fff7d6 !important;">● Hi Kagglers! I'm <strong style="color:#ffe4b5 !important;">Maria Nadeem</strong>, a passionate Data Scientist with strong interest in exploring and applying various data science techniques.</p>
#         <p style="color:#fff7d6 !important;">● I am dedicated to providing impactful decisions through data by exploring datasets and building robust machine learning models. I actively work with various algorithms such as <strong style="color:#ffe4b5 !important;">XGBoost</strong>, <strong style="color:#ffe4b5 !important;">LightGBM</strong>, <strong style="color:#ffe4b5 !important;">CatBoost</strong>, and Neural Networks.</p>
#         <p style="color:#fff7d6 !important;">● I'm excited to share this project on <strong style="color:#ffe4b5 !important;">Predicting Irrigation Need</strong> based on various environmental and agricultural features.</p>
#         <p style="color:#fff7d6 !important;">● This notebook follows a structured pipeline:</p>
#         <!-- Pipeline Box -->
#         <div style="
#             margin: 18px 0;
#             padding: 20px;
#             border-left: 5px solid #22c55e;
#             background: rgba(124,45,18,0.5);
#             border-radius: 14px;
#         ">
#             <ul style="
#                 margin: 0;
#                 padding-left: 22px;
#                 color: #fff7d6 !important;
#             ">
#                 <li style="margin-bottom:8px;">Load train, test, and original datasets and map target labels to numeric format</li>
#                 <li style="margin-bottom:8px;">Perform EDA which includes distribution plots, quadrant analysis, and category-wise target visualization</li>
#                 <li style="margin-bottom:8px;">Identify data “canyons” and sampling gaps using rainfall and soil moisture patterns</li>
#                 <li style="margin-bottom:8px;">Engineer features such as ratios, bins, interaction scores, and flags</li>
#                 <li style="margin-bottom:8px;">Train LightGBM using Stratified K-Fold with target encoding and class balancing</li>
#                 <li>Optimize predictions using Optuna bias tuning and generate final submission file</li>
#             </ul>
#         </div>
#         <p style="color:#fff7d6 !important;">● This approach focuses on <strong style="color:#ffe4b5 !important;">feature engineering and robust validation</strong> rather than just model stacking.</p>
#         <p style="color:#fff7d6 !important;">● The goal is to build a generalizable model that performs well under real-world agricultural variability.</p>
#     </div>
# </div>

# %% [markdown]
# <!-- CONNECT WITH ME HEADING -->
# <p style="
#     background: linear-gradient(135deg,#7c2d12,#9b1c31,#111827);
#     font-family: 'Georgia', serif;
#     color: #fde68a;
#     font-size: 18px;
#     text-align: center;
#     border: 2px solid #22c55e;
#     border-radius: 26px;
#     padding: 22px 35px;
#     width: 90%;
#     margin: 20px auto;
#     box-shadow: 0 14px 40px rgba(0,0,0,0.6);
#     letter-spacing: 2px;
#     font-weight: bold;
# ">
# 🔗 Connect With Me
# </p>
# <!-- MAIN CONTAINER -->
# <div style="
#     width: 90%;
#     margin: 0 auto;
#     padding: 32px;
#     border-radius: 28px;
#     border: 2px solid rgba(34,197,94,0.6);
#     background: radial-gradient(circle at top,#111827,#1f2937,#7c2d12);
#     box-shadow: inset 0 0 25px rgba(255,255,255,0.06), 0 20px 55px rgba(0,0,0,0.65);
#     text-align: center;
# ">
#     <!-- SUBTEXT -->
#     <div style="
#         margin-bottom: 22px;
#         font-family: 'Georgia', serif;
#         color: #ffe4b5;
#         font-size: 15px;
#         opacity: 0.95;
#     ">
#         Let’s connect and build something impactful 🚀
#     </div>
#     <!-- BADGE WRAPPER (CENTER PERFECT ALIGN) -->
#     <div style="
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         flex-wrap: wrap;
#         gap: 18px;
#     ">
#         <div style="padding:6px; border-radius:14px; background: rgba(255,255,255,0.04); border:1px solid rgba(255,255,255,0.08);">
#             <a href="mailto:marianadeem755@gmail.com">
#                 <img src="https://img.shields.io/badge/Email-%23D14836.svg?style=for-the-badge&logo=gmail&logoColor=white">
#             </a>
#         </div>
#         <div style="padding:6px; border-radius:14px; background: rgba(255,255,255,0.04); border:1px solid rgba(255,255,255,0.08);">
#             <a href="https://www.linkedin.com/in/maria-nadeem-4994122aa/">
#                 <img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white">
#             </a>
#         </div>
#         <div style="padding:6px; border-radius:14px; background: rgba(255,255,255,0.04); border:1px solid rgba(255,255,255,0.08);">
#             <a href="https://github.com/marianadeem755">
#                 <img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white">
#             </a>
#         </div>
#         <div style="padding:6px; border-radius:14px; background: rgba(255,255,255,0.04); border:1px solid rgba(255,255,255,0.08);">
#             <a href="https://www.kaggle.com/marianadeem755">
#                 <img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white">
#             </a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <!-- MAIN HEADING -->
# <div style="
#     background: linear-gradient(135deg, #7c2d12, #9b1c31, #111827);
#     font-family: 'Georgia', serif;
#     color: #fde68a;
#     font-size: 21px;
#     text-align: center;
#     border: 2px solid #22c55e;
#     border-radius: 24px;
#     padding: 22px 30px;
#     width: 100%;
#     margin: 25px auto 20px auto;
#     box-shadow: 0 12px 35px rgba(0,0,0,0.55);
#     letter-spacing: 1.5px;
#     font-weight: bold;
# ">
#     📊 Complete Dataset Schema (Train • Test • Sample • Original)
# </div>
#
# <!-- ================= TRAIN.CSV ================= -->
# <div style="
#     padding: 28px;
#     border-radius: 24px;
#     margin: 25px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 15px 40px rgba(0,0,0,0.55);
#     font-family: 'Georgia', serif;
# ">
#     <h2 style="
#         color: #fde68a;
#         margin: 0 0 20px 0;
#         font-size: 23px;
#         font-weight: bold;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         text-shadow: 0 2px 4px rgba(0,0,0,0.7);
#     ">
#         📁 train.csv (21 columns)
#     </h2>
#     <table style="
#         width: auto;
#         max-width: 100%;
#         border-collapse: collapse;
#         background: rgba(255,255,255,0.08);
#         border-radius: 12px;
#         overflow: hidden;
#         box-shadow: 0 8px 20px rgba(0,0,0,0.4);
#     ">
#         <thead>
#             <tr style="background: #9b1c31 !important;">
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📁 File Name
#                 </th>
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📝 Description
#                 </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">id</td><td style="padding: 13px 20px; color: #f5e8c7;">Unique identifier for each record</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Type of soil (Clay, Sandy, Loamy, Silt)</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_pH</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil acidity/alkalinity level</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Moisture</td><td style="padding: 13px 20px; color: #f5e8c7;">Moisture content of soil</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Organic_Carbon</td><td style="padding: 13px 20px; color: #f5e8c7;">Organic carbon content in soil</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Electrical_Conductivity</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil salinity indicator</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Temperature_C</td><td style="padding: 13px 20px; color: #f5e8c7;">Temperature in Celsius</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Humidity</td><td style="padding: 13px 20px; color: #f5e8c7;">Humidity percentage</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall amount in mm</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Sunlight_Hours</td><td style="padding: 13px 20px; color: #f5e8c7;">Daily sunlight duration</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Wind_Speed_kmh</td><td style="padding: 13px 20px; color: #f5e8c7;">Wind speed in km/h</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Type of crop grown</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Growth_Stage</td><td style="padding: 13px 20px; color: #f5e8c7;">Growth stage of crop</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Season</td><td style="padding: 13px 20px; color: #f5e8c7;">Agricultural season</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation system used</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Water_Source</td><td style="padding: 13px 20px; color: #f5e8c7;">Source of irrigation water</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Field_Area_hectare</td><td style="padding: 13px 20px; color: #f5e8c7;">Field size in hectares</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Mulching_Used</td><td style="padding: 13px 20px; color: #f5e8c7;">Whether mulching is used</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Previous_Irrigation_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Previous irrigation amount</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Region</td><td style="padding: 13px 20px; color: #f5e8c7;">Geographical region</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Need</td><td style="padding: 13px 20px; color: #f5e8c7;">Target variable (Low, medium or High irrigation requirement)</td></tr>
#         </tbody>
#     </table>
# </div>
#
# <!-- ================= TEST.CSV ================= -->
# <div style="
#     padding: 28px;
#     border-radius: 24px;
#     margin: 25px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 15px 40px rgba(0,0,0,0.55);
#     font-family: 'Georgia', serif;
# ">
#     <h2 style="
#         color: #fde68a;
#         margin: 0 0 20px 0;
#         font-size: 23px;
#         font-weight: bold;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         text-shadow: 0 2px 4px rgba(0,0,0,0.7);
#     ">
#         📁 test.csv (20 columns)
#     </h2>
#     <table style="
#         width: auto;
#         max-width: 100%;
#         border-collapse: collapse;
#         background: rgba(255,255,255,0.08);
#         border-radius: 12px;
#         overflow: hidden;
#         box-shadow: 0 8px 20px rgba(0,0,0,0.4);
#     ">
#         <thead>
#             <tr style="background: #9b1c31 !important;">
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📁 File Name
#                 </th>
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📝 Description
#                 </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">id</td><td style="padding: 13px 20px; color: #f5e8c7;">Unique identifier for each record</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Type of soil (Clay, Sandy, Loamy, Silt)</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_pH</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil acidity level</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Moisture</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil moisture content</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Organic_Carbon</td><td style="padding: 13px 20px; color: #f5e8c7;">Organic carbon content</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Electrical_Conductivity</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil salinity level</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Temperature_C</td><td style="padding: 13px 20px; color: #f5e8c7;">Temperature in Celsius</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Humidity</td><td style="padding: 13px 20px; color: #f5e8c7;">Humidity percentage</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall amount</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Sunlight_Hours</td><td style="padding: 13px 20px; color: #f5e8c7;">Sunlight exposure hours</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Wind_Speed_kmh</td><td style="padding: 13px 20px; color: #f5e8c7;">Wind speed</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Crop type</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Growth_Stage</td><td style="padding: 13px 20px; color: #f5e8c7;">Growth stage</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Season</td><td style="padding: 13px 20px; color: #f5e8c7;">Season type</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation method</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Water_Source</td><td style="padding: 13px 20px; color: #f5e8c7;">Water source</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Field_Area_hectare</td><td style="padding: 13px 20px; color: #f5e8c7;">Field size</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Mulching_Used</td><td style="padding: 13px 20px; color: #f5e8c7;">Mulching usage</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Previous_Irrigation_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Previous irrigation</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Region</td><td style="padding: 13px 20px; color: #f5e8c7;">Region</td></tr>
#         </tbody>
#     </table>
# </div>
#
# <!-- ================= SAMPLE SUBMISSION ================= -->
# <div style="
#     padding: 28px;
#     border-radius: 24px;
#     margin: 25px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 15px 40px rgba(0,0,0,0.55);
#     font-family: 'Georgia', serif;
# ">
#     <h2 style="
#         color: #fde68a;
#         margin: 0 0 20px 0;
#         font-size: 23px;
#         font-weight: bold;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         text-shadow: 0 2px 4px rgba(0,0,0,0.7);
#     ">
#         📁 sample_submission.csv
#     </h2>
#     <table style="
#         width: auto;
#         max-width: 100%;
#         border-collapse: collapse;
#         background: rgba(255,255,255,0.08);
#         border-radius: 12px;
#         overflow: hidden;
#         box-shadow: 0 8px 20px rgba(0,0,0,0.4);
#     ">
#         <thead>
#             <tr style="background: #9b1c31 !important;">
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📁 File Name
#                 </th>
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📝 Description
#                 </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">id</td><td style="padding: 13px 20px; color: #f5e8c7;">Unique identifier</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Need</td><td style="padding: 13px 20px; color: #f5e8c7;">Predicted irrigation requirement</td></tr>
#         </tbody>
#     </table>
# </div>
#
# <!-- ================= ORIGINAL DATASET ================= -->
# <div style="
#     padding: 28px;
#     border-radius: 24px;
#     margin: 25px 0;
#     background: radial-gradient(circle at top left, #7c2d12, #3f1d0f 60%, #111827);
#     border: 2px solid #22c55e;
#     box-shadow: 0 15px 40px rgba(0,0,0,0.55);
#     font-family: 'Georgia', serif;
# ">
#     <h2 style="
#         color: #fde68a;
#         margin: 0 0 20px 0;
#         font-size: 23px;
#         font-weight: bold;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         text-shadow: 0 2px 4px rgba(0,0,0,0.7);
#     ">
#         📁 original dataset
#     </h2>
#     <table style="
#         width: auto;
#         max-width: 100%;
#         border-collapse: collapse;
#         background: rgba(255,255,255,0.08);
#         border-radius: 12px;
#         overflow: hidden;
#         box-shadow: 0 8px 20px rgba(0,0,0,0.4);
#     ">
#         <thead>
#             <tr style="background: #9b1c31 !important;">
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📁 File Name
#                 </th>
#                 <th style="
#                     padding: 18px 22px;
#                     text-align: left;
#                     color: #fde68a !important;
#                     font-weight: bold;
#                     font-size: 16.5px;
#                     border-bottom: 5px solid #22c55e;
#                     background: #9b1c31 !important;
#                 ">
#                     📝 Description
#                 </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Type of soil</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_pH</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil pH level</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Soil_Moisture</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil moisture content</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Organic_Carbon</td><td style="padding: 13px 20px; color: #f5e8c7;">Organic carbon level</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Electrical_Conductivity</td><td style="padding: 13px 20px; color: #f5e8c7;">Soil salinity</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Temperature_C</td><td style="padding: 13px 20px; color: #f5e8c7;">Temperature</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Humidity</td><td style="padding: 13px 20px; color: #f5e8c7;">Humidity</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Rainfall</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Sunlight_Hours</td><td style="padding: 13px 20px; color: #f5e8c7;">Sunlight hours</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Wind_Speed_kmh</td><td style="padding: 13px 20px; color: #f5e8c7;">Wind speed</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Crop type</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Crop_Growth_Stage</td><td style="padding: 13px 20px; color: #f5e8c7;">Growth stage</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Season</td><td style="padding: 13px 20px; color: #f5e8c7;">Season</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Type</td><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation method</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Water_Source</td><td style="padding: 13px 20px; color: #f5e8c7;">Water source</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Field_Area_hectare</td><td style="padding: 13px 20px; color: #f5e8c7;">Field size</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Mulching_Used</td><td style="padding: 13px 20px; color: #f5e8c7;">Mulching usage</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Previous_Irrigation_mm</td><td style="padding: 13px 20px; color: #f5e8c7;">Previous irrigation</td></tr>
#             <tr style="background: #1f2937;"><td style="padding: 13px 20px; color: #f5e8c7;">Region</td><td style="padding: 13px 20px; color: #f5e8c7;">Region</td></tr>
#             <tr style="background: #2a3a4f;"><td style="padding: 13px 20px; color: #f5e8c7;">Irrigation_Need</td><td style="padding: 13px 20px; color: #f5e8c7;">Target variable</td></tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# <!-- MAIN TITLE -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:22px;
#     font-weight:800;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.6);
#     letter-spacing:1px;
# ">
# 🌾 Dataset Overview (Irrigation Need Prediction)
# </div>
#
# <!-- DESCRIPTION BOX -->
# <div style="
#     margin-top:20px;
#     padding:22px;
#     border-radius:18px;
#     background:#111827;
#     border:1px solid #374151;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.6;
#     box-shadow:0 10px 30px rgba(0,0,0,0.5);
# ">
#
# <p>
# This dataset is built for a <b>supervised machine learning classification problem</b> where the aim is to determine whether a farm field needs irrigation or not.
# Each row represents an agricultural scenario described by soil properties, weather conditions, crop details, and farm management practices.
# </p>
#
# <p>
# <b>🎯 Target Variable:</b><br>
# • <span style="color:#22c55e;"><b>Irrigation_Need</b></span> irrigation requirement such as low , medium or High
# </p>
#
# </div>
#
# <!-- SOIL SECTION -->
# <div style="margin-top:25px; padding:20px; border-radius:15px; background:#1f2937; border-left:5px solid #22c55e;">
# <h3 style="color:#22c55e;">🌱 Soil & Land Characteristics</h3>
#
# <p style="color:#ffffff;">
# These features capture the physical and chemical state of the field:
# </p>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li><b>Soil_Type</b> (categorical): clay / sandy / loamy / silt</li>
# <li><b>Soil_pH</b>: soil acidity/alkalinity level described by the values in this Dataset</li>
# <li><b>Soil_Moisture</b>: current water content in soil</li>
# <li><b>Organic_Carbon</b>: organic matter level in soil</li>
# <li><b>Electrical_Conductivity</b>: salinity indicator of soil</li>
# </ul>
#
# <p style="color:#cbd5e1;">
# These features define how well soil retains water and directly influence irrigation need.
# </p>
# </div>
#
# <!-- WEATHER SECTION -->
# <div style="margin-top:25px; padding:20px; border-radius:15px; background:#0f172a; border-left:5px solid #38bdf8;">
# <h3 style="color:#38bdf8;">🌦️ Weather & Atmospheric Conditions</h3>
#
# <p style="color:#ffffff;">
# These describe environmental factors affecting evaporation and moisture loss:
# </p>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li><b>Rainfall_mm</b>: precipitation level</li>
# <li><b>Temperature_C</b>: temperature in Celsius</li>
# <li><b>Humidity</b>: atmospheric moisture percentage</li>
# <li><b>Sunlight_Hours</b>: daily sunlight exposure</li>
# <li><b>Wind_Speed_kmh</b>: wind-driven evaporation factor</li>
# </ul>
#
# <p style="color:#cbd5e1;">
# High rainfall reduces irrigation need, while high temperature and wind increase it.
# </p>
# </div>
#
# <!-- CROP SECTION -->
# <div style="margin-top:25px; padding:20px; border-radius:15px; background:#111827; border-left:5px solid #f59e0b;">
# <h3 style="color:#f59e0b;">🌾 Crop & Farm Management Context</h3>
#
# <p style="color:#ffffff;">
# These features represent farming decisions and crop water demand:
# </p>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li><b>Crop_Type</b>: type of cultivated crop</li>
# <li><b>Crop_Growth_Stage</b>: sowing / vegetative / flowering / harvest</li>
# <li><b>Season</b>: agricultural season type</li>
# <li><b>Irrigation_Type</b>: irrigation method used</li>
# <li><b>Water_Source</b>: source of irrigation water</li>
# <li><b>Field_Area_hectare</b>: size of farmland</li>
# <li><b>Mulching_Used</b>: whether mulching is applied</li>
# <li><b>Previous_Irrigation_mm</b>: past irrigation amount</li>
# <li><b>Region</b>: geographic and climatic zone</li>
# </ul>
#
# <p style="color:#cbd5e1;">
# These features help the model learn that irrigation need depends not just on weather, but also farming practices.
# </p>
# </div>
#
# <!-- TARGET SECTION -->
# <div style="margin-top:25px; padding:20px; border-radius:15px; background:#1f2937; border-left:5px solid #22c55e;">
# <h3 style="color:#22c55e;">🎯 Target Variable</h3>
#
# <p style="color:#ffffff;">
# <b>Irrigation_Need</b> represents whether irrigation is required.
# In raw form it may appear as categorical labels (Low, Medium  and High).
# </p>
# </div>
#
# <!-- DATA TYPE SECTION -->
# <div style="margin-top:25px; padding:20px; border-radius:15px; background:#0f172a; border-left:5px solid #a78bfa;">
# <h3 style="color:#a78bfa;">🔢 Data Types & Modeling Structure</h3>
#
# <p style="color:#ffffff;">
# The dataset contains two major types of features:
# </p>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li><b>Categorical Features:</b> Soil_Type, Crop_Type, Crop_Growth_Stage, Season, Irrigation_Type, Water_Source, Mulching_Used, Region</li>
# <li><b>Numerical Features:</b> Soil_pH, Soil_Moisture, Sunlight_hors, Wind_Speed_kmh, Rainfall_mm, Temperature_C, Humidity, etc.</li>
# </ul>
#
# <p style="color:#cbd5e1;">
# Categorical variables capture discrete agricultural patterns, while numerical variables provide continuous signals for model learning.
# </p>
# </div>

# %% [markdown]
# <!-- MAIN TITLE -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#1f2937,#7c2d12);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:22px;
#     font-weight:800;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.6);
#     letter-spacing:1px;
# ">
# 🌟 Why This Dataset is Useful and Informative
# </div>
#
# <!-- INTRO BOX -->
# <div style="
#     margin-top:20px;
#     padding:22px;
#     border-radius:18px;
#     background:#111827;
#     border:1px solid #374151;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.7;
#     box-shadow:0 10px 30px rgba(0,0,0,0.5);
# ">
# This dataset is <b>well-structured and highly meaningful</b> because it brings various multiple real-world agricultural factors that directly influence irrigation decisions in farming systems.
# </div>
#
# <!-- ENVIRONMENT -->
# <div style="margin-top:22px; padding:20px; border-radius:15px; background:#0f172a; border-left:5px solid #38bdf8;">
# <h3 style="color:#38bdf8;">🌦️ Rich Environmental Information</h3>
# <p style="color:#ffffff;">
# It includes key weather-related features such as <b>rainfall, temperature, humidity, wind speed, and sunlight hours</b> that directly affect water demand and evaporation rates in crops.
# </p>
# </div>
#
# <!-- SOIL -->
# <div style="margin-top:22px; padding:20px; border-radius:15px; background:#1f2937; border-left:5px solid #22c55e;">
# <h3 style="color:#22c55e;">🌱 Detailed Soil Properties</h3>
# <p style="color:#ffffff;">
# Soil characteristics like <b>pH, organic carbon, electrical conductivity, and moisture levels</b> describe how efficiently soil retains and supplies water to crops.
# </p>
# </div>
#
# <!-- CROP -->
# <div style="margin-top:22px; padding:20px; border-radius:15px; background:#111827; border-left:5px solid #f59e0b;">
# <h3 style="color:#f59e0b;">🌾 Crop Growth Context</h3>
# <p style="color:#ffffff;">
# Features such as <b>crop type, growth stage, and season</b> help understand how water requirements vary across different agricultural conditions and crop lifecycles.
# </p>
# </div>
#
# <!-- FARM MANAGEMENT -->
# <div style="margin-top:22px; padding:20px; border-radius:15px; background:#0f172a; border-left:5px solid #a78bfa;">
# <h3 style="color:#a78bfa;">💧 Agricultural Management Factors</h3>
# <p style="color:#ffffff;">
# Real-world farming decisions are captured through <b>irrigation type, water source, mulching usage, and previous irrigation history</b>, making the dataset practically realistic.
# </p>
# </div>
#
# <!-- DATA QUALITY -->
# <div style="margin-top:22px; padding:20px; border-radius:15px; background:#1f2937; border-left:5px solid #22c55e;">
# <h3 style="color:#22c55e;">🧹 Clean and Well-Organized Data</h3>
# <p style="color:#ffffff;">
# The dataset is structured with <b>minimal data quality issues</b>, making it easy to analyze, preprocess, and apply machine learning models effectively.
# </p>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Import Libraries</p>

# %%
# import libraries
import os
import gc
import warnings
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import lightgbm as lgb
import io
from IPython.display import display, HTML
import random
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import TargetEncoder
from sklearn.utils.class_weight import compute_sample_weight
import optuna
# ignore warnings
warnings.filterwarnings('ignore')
optuna.logging.set_verbosity(optuna.logging.WARNING)
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 200
seed = 42
random.seed(seed)
np.random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Competiton Data Overview</p>

# %%
# TABLE STYLING (FIXED: WHITE TEXT + HIGH CONTRAST)
def style_table(df):
    styled_df = df.style.set_table_styles([
        {"selector": "th", "props": [
            ("color", "#ffffff"),
            ("background-color", "#9b1c31"),
            ("font-weight", "bold"),
            ("font-size", "14px"),
            ("padding", "10px"),
            ("border", "1px solid #ffccd5"),
            ("text-shadow", "0 0 6px #000000")
        ]},
        {"selector": "td", "props": [
            ("text-align", "center"),
            ("color", "#ffffff"),
            ("background-color", "#1f2937"),
            ("border", "1px solid #374151"),
            ("padding", "8px")
        ]},
        {"selector": "table", "props": [
            ("background-color", "#111827"),
            ("border-radius", "12px")
        ]}
    ]).hide(axis="index")
    return styled_df.to_html()


# RANDOM COLOR
def generate_random_color():
    return "#{:02x}{:02x}{:02x}".format(
        random.randint(120, 255),
        random.randint(80, 200),
        random.randint(120, 255)
    )


# STYLED HEADINGS (FIXED VISIBILITY)
def styled_heading(text, gradient, text_color='#ffffff', border_color='#22c55e', font_size='24px'):
    return f"""
    <div style="
        background: {gradient};
        background-size: 300% 300%;
        animation: gradientMove 6s ease infinite;
        text-align: center;
        color: {text_color};
        padding: 22px 40px;
        border-radius: 25px;
        font-family: 'Poppins', sans-serif;
        font-weight: 800;
        font-size: {font_size};
        letter-spacing: 2px;
        border: 3px solid {border_color};
        box-shadow: 0px 0px 25px rgba(0,0,0,0.6);
        margin: 25px 0;
    ">
        {text}
    </div>
    <style>
        @keyframes gradientMove {{
            0% {{ background-position: 0% 50%; }}
            50% {{ background-position: 100% 50%; }}
            100% {{ background-position: 0% 50%; }}
        }}
    </style>
    """


# SECTION HEADER (FIXED)
def section_header(title, gradient):
    return f"""
    <div style="
        background: {gradient};
        color: #ffffff;
        text-align: center;
        padding: 12px 25px;
        border-radius: 12px;
        font-family: 'Poppins', sans-serif;
        font-weight: 700;
        font-size: 20px;
        margin-top: 15px;
        box-shadow: 0px 4px 12px rgba(0,0,0,0.5);
    ">
        {title}
    </div>
    """


# MAIN FUNCTION (UNCHANGED LOGIC)
def print_dataset_analysis(dataset, dataset_name, n_top=5, palette_index=0):

    main_gradients = [
        "linear-gradient(90deg, #111827, #7c2d12, #1f2937)",
        "linear-gradient(90deg, #1f2937, #9b1c31, #111827)",
        "linear-gradient(90deg, #0f172a, #7c2d12, #111827)"
    ]

    sub_gradients = [
        "linear-gradient(90deg, #9b1c31, #1f2937)",
        "linear-gradient(90deg, #7c2d12, #111827)",
        "linear-gradient(90deg, #1f2937, #9b1c31)"
    ]

    heading_gradient = main_gradients[palette_index % len(main_gradients)]
    sub_gradient = sub_gradients[palette_index % len(sub_gradients)]

    display(HTML(styled_heading(f"{dataset_name} Overview", heading_gradient)))

    # SHAPE
    display(HTML(section_header("📏 Shape of the Dataset", sub_gradient)))
    display(HTML(f"""
    <div style='
        color:#ffffff;
        font-family:Poppins;
        font-size:16px;
        font-weight:600;
        text-align:center;
        background:#111827;
        border:1px solid #374151;
        padding:10px;
        border-radius:10px;
        margin:10px 0;
    '>
        {dataset.shape[0]} rows × {dataset.shape[1]} columns
    </div>
    """))

    # HEAD
    display(HTML(section_header("👀 First Rows", sub_gradient)))
    display(HTML(style_table(dataset.head(n_top))))

    # STATS
    display(HTML(section_header("📊 Summary Statistics", sub_gradient)))
    display(HTML(style_table(dataset.describe())))

    # NULLS
    display(HTML(section_header("🚨 Null Values", sub_gradient)))
    null_counts = dataset.isnull().sum()
    if null_counts.sum() == 0:
        display(HTML("<p style='color:#22c55e;font-weight:600;'>✅ No null values found.</p>"))
    else:
        null_df = null_counts[null_counts > 0].to_frame("Null Values")
        null_df["Column"] = null_df.index
        display(HTML(style_table(null_df)))

    # DUPLICATES
    display(HTML(section_header("🔁 Duplicate Rows", sub_gradient)))
    display(HTML(f"<p style='color:#f87171;font-weight:600;'>{dataset.duplicated().sum()} duplicates found.</p>"))

    # DTYPE
    display(HTML(section_header("🔢 Data Types", sub_gradient)))
    dtypes_df = pd.DataFrame({
        "Column": dataset.columns,
        "Data Type": [dataset[col].dtype for col in dataset.columns]
    })
    display(HTML(style_table(dtypes_df)))

    # COLUMNS
    display(HTML(section_header("📋 Column Names", sub_gradient)))
    cols_html = ", ".join([
        f"<span style='color:#ffffff;font-weight:600'>{c}</span>"
        for c in dataset.columns
    ])
    display(HTML(f"<div style='color:white'>{cols_html}</div>"))

    # UNIQUE
    display(HTML(section_header("🔍 Unique Values", sub_gradient)))
    unique_df = pd.DataFrame({
        "Column": dataset.columns,
        "Unique Values": [dataset[col].nunique() for col in dataset.columns]
    })
    display(HTML(style_table(unique_df)))

    # INFO
    display(HTML(section_header("ℹ️ Dataset Info", sub_gradient)))
    buffer = io.StringIO()
    dataset.info(buf=buffer)
    display(HTML(f"<pre style='background:#111827;color:#ffffff;padding:12px;border-radius:10px'>{buffer.getvalue()}</pre>"))

# LOAD DATA
df_train = pd.read_csv("/kaggle/input/competitions/playground-series-s6e4/train.csv")
df_test = pd.read_csv("/kaggle/input/competitions/playground-series-s6e4/test.csv")
sample_sub = pd.read_csv("/kaggle/input/competitions/playground-series-s6e4/sample_submission.csv")
df_org = pd.read_csv("/kaggle/input/datasets/miadul/irrigation-water-requirement-prediction-dataset/irrigation_prediction.csv")  # if exists

# DISPLAY ALL
print_dataset_analysis(df_train, "Training Data", palette_index=0)
print_dataset_analysis(df_test, "Testing Data", palette_index=1)
print_dataset_analysis(sample_sub, "Sample Submission Data", palette_index=2)
print_dataset_analysis(df_org, "Original Dataset", palette_index=3)
# Out:
#     <div style="
#         background: linear-gradient(90deg, #111827, #7c2d12, #1f2937);
#         background-size: 300% 300%;
#         animation: gradientMove 6s ease infinite;
#         text-align: center;
#         color: #ffffff;
#         padding: 22px 40px;
#         border-radius: 25px;
#         font-family: 'Poppins', sans-serif;
#         font-weight: 800;
#         font-size: 24px;
#         letter-spacing: 2px;
#         border: 3px solid #22c55e;
#         box-shadow: 0px 0px 25px rgba(0,0,0,0.6);
#         margin: 25px 0;
#     ">
#         Training Data Overview
#     </div>
#     <style>
#         @keyframes gradientMove {
#             0% { background-position: 0% 50%; }
#             50% { background-position: 100% 50%; }
#             100% { background-position: 0% 50%; }
#         }
#     </style>
#     <div style="
#         background: linear-gradient(90deg, #9b1c31, #1f2937);
#         color: #ffffff;
#         text-align: center;
# ...

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Data Loading</p>

# %%
target_col = 'Irrigation_Need'
target_mapping = {'Low': 0, 'Medium': 1, 'High': 2}
inverse_mapping = {0: 'Low', 1: 'Medium', 2: 'High'}

df_train['target_numeric'] = df_train[target_col].map(target_mapping)
df_org['target_numeric'] = df_org[target_col].map(target_mapping)

print(f" Data has loaded Successfully!")
print(f"   df_train: {df_train.shape} | df_test: {df_test.shape} | df_org: {df_org.shape}")
print(f"   Baseline High-Class Rate: {(df_train['target_numeric'] == 2).mean():.2%}")
# Out:
#  Data has loaded Successfully!
#    df_train: (630000, 22) | df_test: (270000, 20) | df_org: (10000, 21)
#    Baseline High-Class Rate: 3.33%

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Lets do Canyon Analysis by Comparing Real vs Synthetic Rainfall Distributions</p>

# %%
def plot_canyon_analysis(train_df, org_df):
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np
    
    plt.style.use("dark_background")
    fig, axes = plt.subplots(2, 1, figsize=(18, 12), facecolor="#0f172a")
    
    # KDE DISTRIBUTION PLOT
    sns.kdeplot(
        org_df['Rainfall_mm'],
        ax=axes[0],
        label='Original Data',
        color='#38bdf8',
        linewidth=3,
        fill=True,
        alpha=0.35
    )
    sns.kdeplot(
        train_df['Rainfall_mm'],
        ax=axes[0],
        label='Synthetic Data',
        color='#f97316',
        linewidth=3,
        fill=True,
        alpha=0.35
    )
    axes[0].set_title(
        'Rainfall Distribution Comparison',
        fontsize=16,
        fontweight='bold',
        color='white'
    )
    axes[0].set_xlabel("Rainfall (mm)", fontsize=13, color="white")
    axes[0].set_ylabel("Density", fontsize=13, color="white")
    axes[0].legend(facecolor="#111827", edgecolor="white")
    axes[0].grid(True, alpha=0.25, linestyle='--')
    axes[0].set_facecolor("#111827")
    
    # IMPROVED SECOND PLOT WITH TWIN Y-AXIS
    bins = np.linspace(0, 2500, 80)
    hist_org, _ = np.histogram(org_df['Rainfall_mm'], bins=bins, density=True)
    hist_train, _ = np.histogram(train_df['Rainfall_mm'], bins=bins, density=True)
    ratio = hist_train / (hist_org + 1e-8)
    
    ax1 = axes[1]                   
    ax2 = ax1.twinx()                
    
    # Original Density 
    ax1.plot(
        bins[:-1],
        hist_org,
        color='#38bdf8',
        linewidth=2.8,
        label='Original Density',
        alpha=0.95
    )
    # Synthetic Density 
    ax1.plot(
        bins[:-1],
        hist_train,
        color='#f97316',
        linewidth=2.8,
        label='Synthetic Density',
        alpha=0.95
    )
    # Density Ratio 
    ax2.plot(
        bins[:-1],
        ratio,
        color='#ef4444',
        linewidth=3.2,
        label='Density Ratio (Synthetic / Original)'
    )
    
    ax1.axhline(0, color='white', linestyle='--', linewidth=1, alpha=0.3)
    ax2.axhline(1.0, color='white', linestyle='--', linewidth=1.5, alpha=0.7)
    
    # Styling
    ax1.set_title(
        'Density Comparison & Ratio (Synthetic vs Original)',
        fontsize=16,
        fontweight='bold',
        color='white'
    )
    ax1.set_xlabel("Rainfall (mm)", fontsize=13, color="white")
    ax1.set_ylabel("Density", fontsize=13, color="#38bdf8")         
    ax2.set_ylabel("Density Ratio", fontsize=13, color="#ef4444")   
    
    # Legends
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2, 
               facecolor="#111827", edgecolor="white", loc='upper right')
    
    ax1.grid(True, alpha=0.25, linestyle='--')
    ax1.set_facecolor("#111827")
    
    plt.suptitle(
        'Synthetic Generator Sampling Deficit Analysis',
        fontsize=20,
        fontweight='bold',
        color='white'
    )
    plt.tight_layout()
    plt.show()

# Call the function
plot_canyon_analysis(df_train, df_org)

# %% [markdown]
# <!-- HEADER -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:20px;
#     font-weight:900;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.7);
# ">
# 📊 Rainfall Distribution Comparison Analysis
# </div>
#
# <!-- SECTION 1 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #38bdf8;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#38bdf8;">1) Main Comparison (Rainfall Distribution)</h3>
#
# <ul>
# <li>The synthetic rainfall distribution is generally shaped like the original rainfall distribution.</li>
# <li>By analyzing original and Competition Datasets, it is determined that both datasets show that most rainfall values are concentrated in the middle to higher rainfall ranges.</li>
# <li>The synthetic curve follows the original curve very well, but not exactly at every point.</li>
# </ul>
# </div>
#
# <!-- SECTION 2 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#1f2937;
#     border-left:5px solid #22c55e;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#22c55e;">2) Match Strength (Overall Similarity)</h3>
#
# <ul>
# <li>The overall pattern is similar, which means the synthetic data is capturing the basic rainfall behavior.</li>
# <li>Small mismatches appear where the synthetic curve is a little higher or lower than the original.</li>
# </ul>
# </div>
#
# <!-- SECTION 3 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#0f172a;
#     border-left:5px solid #f59e0b;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#f59e0b;">3) Density Differences (Where Synthetic Deviates)</h3>
#
# <ul>
# <li>Some rainfall ranges show high differences:</li>
# <li>In some regions, synthetic data has more frequency than original.</li>
# <li>In other regions, synthetic data has less frequency than original.</li>
# <li>This is normal and it shows that the synthetic data is not a perfectly follow original data but could be relateable.</li>
# </ul>
# </div>
#
# <!-- SECTION 4 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #ef4444;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#ef4444;">4) Ratio Explanation (Synthetic vs Original)</h3>
#
# <ul>
# <li>The ratio line tells that how synthetic data compares to original data:</li>
# <li>Ratio ~ 1: synthetic matches original well.</li>
# <li>Ratio > 1: synthetic is higher than original (represents overestimation).</li>
# <li>Ratio < 1: synthetic is lower than original (represents underestimation).</li>
# <li>Most of the time the ratio is not very far from 1, so the match is very good, and some spikes where it differs more.</li>
# </ul>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;letter-spacing:1.2px;line-height:1.8;">Lets have sneak peak of Target Distribution | Irrigation Need by Crop Type, Region & Mulching</p>

# %%
def plot_target_analysis(df_train, target_col):
    import matplotlib.pyplot as plt
    import seaborn as sns

    plt.style.use("dark_background")

    fig, axes = plt.subplots(3, 1, figsize=(18, 18), facecolor="#0f172a")
    
    # Crop Type
    ax0 = sns.countplot(
        data=df_train,
        x='Crop_Type',
        hue=target_col,
        ax=axes[0],
        palette=['#38bdf8', '#f97316', '#22c55e']  # low, medium, high
    )

    axes[0].set_title('Irrigation Need by Crop Type', fontweight='bold', color='white', pad=12)
    axes[0].set_xlabel("Crop Type", color="white")
    axes[0].set_ylabel("Count", color="white")
    axes[0].set_facecolor("#111827")
    axes[0].grid(True, alpha=0.2)

    for container in ax0.containers:
        ax0.bar_label(container, color="white", fontsize=9)

    # Region
    ax1 = sns.countplot(
        data=df_train,
        x='Region',
        hue=target_col,
        ax=axes[1],
        palette=['#ef4444', '#38bdf8', '#22c55e']  # low, medium, high
    )

    axes[1].set_title('Irrigation Need by Region', fontweight='bold', color='white', pad=12)
    axes[1].set_xlabel("Region", color="white")
    axes[1].set_ylabel("Count", color="white")
    axes[1].set_facecolor("#111827")
    axes[1].grid(True, alpha=0.2)

    for container in ax1.containers:
        ax1.bar_label(container, color="white", fontsize=9)

    # Mulching Used
    ax2 = sns.countplot(
        data=df_train,
        x='Mulching_Used',
        hue=target_col,
        ax=axes[2],
        palette=['#f97316', '#38bdf8', '#22c55e']  # low, medium, high
    )

    axes[2].set_title('Irrigation Need by Mulching Usage', fontweight='bold', color='white', pad=12)
    axes[2].set_xlabel("Mulching Used", color="white")
    axes[2].set_ylabel("Count", color="white")
    axes[2].set_facecolor("#111827")
    axes[2].grid(True, alpha=0.2)

    for container in ax2.containers:
        ax2.bar_label(container, color="white", fontsize=9)

    fig.suptitle(
        'Target Distribution Across Key Agricultural Features',
        fontsize=18,
        fontweight='bold',
        color='white',
        y=0.995   
    )

    plt.tight_layout(rect=[0, 0, 1, 0.96])

    plt.show()


plot_target_analysis(df_train, target_col)

# %% [markdown]
# <!-- HEADER -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:20px;
#     font-weight:900;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.7);
# ">
# 🌾 Target Distribution Analysis (Irrigation Need)
# </div>
#
# <!-- SECTION 1 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #38bdf8;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#38bdf8;">1) Target Distribution (Across Key Agricultural Features)</h3>
#
# <ul>
# <li>These bar charts shows that how irrigation need is distributed across important farming factors.</li>
# <li>Categories are based on Low, Medium and High irrigation need.</li>
# <li>The goal is that to check whether the irrigation-need pattern looks consistent across different features.</li>
# </ul>
# </div>
#
# <!-- SECTION 2 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#1f2937;
#     border-left:5px solid #22c55e;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#22c55e;">2) Irrigation Need by Crop Type</h3>
#
# <ul>
# <li>Most crops have the highest counts in the “Low” irrigation need category.</li>
# <li>Low irrigation need is always much higher compared to the Medium and High category.</li>
# <li>Crops with the High counts (as we can check in the bars) are generally that requires less water more often.</li>
# <li>Hence, the chart shows clear differences between crops and how often they fall into each irrigation-need level.</li>
# </ul>
# </div>
#
# <!-- SECTION 3 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#0f172a;
#     border-left:5px solid #f59e0b;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#f59e0b;">3) Irrigation Need by Region</h3>
#
# <ul>
# <li>The East, South, West, and Central regions all show the same general trend:</li>
# <li>High irrigation need is the least common</li>
# <li>Low irrigation need is the more common</li>
# <li>Some regions have slightly different Medium and Low balance, but the pattern remains similar.</li>
# <li>This suggests irrigation needs vary by region, but less drastically in category structure.</li>
# </ul>
# </div>
#
# <!-- SECTION 4 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #ef4444;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#ef4444;">4) Irrigation Need by Mulching Usage</h3>
#
# <ul>
# <li>The “Mulching Usage” chart compares No vs Yes.</li>
# <li>When Mulching = Yes, the Low irrigation need count is much larger than the other categories.</li>
# <li>When Mulching = No, Medium irrigation need count is higher, but the distribution of medium and Low are mostly high.</li>
# <li>Low irrigation need stays very high in both cases, meaning high-need samples are rare overall.</li>
# <li>This indicates mulching affects irrigation-need distribution, especially by shifting the counts between Medium and Low.</li>
# </ul>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Lets Visualize Key Numeric Features Distribution by Irrigation Need</p>

# %%
def plot_numeric_distribution(df_train, target_col):
    import matplotlib.pyplot as plt
    import seaborn as sns

    key_numerics = [
        'Soil_Moisture',
        'Rainfall_mm',
        'Temperature_C',
        'Humidity'
    ]

    plt.style.use("dark_background")

    fig, axes = plt.subplots(2, 2, figsize=(16, 10), facecolor="#0f172a")
    axes = axes.ravel()

    palette = ['#38bdf8', '#f97316', '#22c55e']  # low, medium, high

    for i, col in enumerate(key_numerics):
        ax = axes[i]

        sns.boxplot(
            data=df_train,
            x=target_col,
            y=col,
            ax=ax,
            palette=palette,
            width=0.6,
            linewidth=1.5
        )
        ax.set_title(
            f'{col} by {target_col}',
            fontweight='bold',
            color='white',
            pad=12
        )

        ax.set_xlabel(target_col, color="white")
        ax.set_ylabel(col, color="white")
        ax.set_facecolor("#111827")
        ax.grid(True, alpha=0.25)
        ax.tick_params(colors='white')
        
        # MEAN & MAX VALUES
        grouped = df_train.groupby(target_col)[col]

        means = grouped.mean()
        maxs = grouped.max()

        for j, cls in enumerate(means.index):
            mean_val = means[cls]
            max_val = maxs[cls]

            # MEAN label
            ax.text(
                j - 0.12,
                mean_val,
                f"Mean: {mean_val:.2f}",
                ha='center',
                va='bottom',
                fontsize=9,
                color='#38bdf8',
                fontweight='bold',
                bbox=dict(facecolor='#111827', edgecolor='#38bdf8', boxstyle='round,pad=0.25', alpha=0.8)
            )

            # MAX label
            ax.text(
                j + 0.12,
                max_val,
                f"Max: {max_val:.2f}",
                ha='center',
                va='bottom',
                fontsize=9,
                color='#f97316',
                fontweight='bold',
                bbox=dict(facecolor='#111827', edgecolor='#f97316', boxstyle='round,pad=0.25', alpha=0.8)
            )

    fig.suptitle(
        'Key Numeric Feature Distribution (Mean & Max Analysis)',
        fontsize=18,
        fontweight='bold',
        color='white',
        y=0.98
    )

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()


plot_numeric_distribution(df_train, target_col)

# %% [markdown]
# <!-- HEADER -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:20px;
#     font-weight:900;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.7);
# ">
# 📊 Feature vs Irrigation Need Analysis
# </div>
#
# <!-- SECTION 1 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #38bdf8;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#38bdf8;">1) Soil Moisture vs Irrigation Need</h3>
#
# <ul>
# <li>High irrigation need has the lowest soil moisture values.</li>
# <li>Low irrigation need has the highest soil moisture (it is represented by the mean, which can be visibly clear by this Boxplot).</li>
# <li>The means decrease from Low to Medium and then to High, meaning soil moisture tends to drop as irrigation need increases.</li>
# </ul>
# </div>
#
# <!-- SECTION 2 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#1f2937;
#     border-left:5px solid #22c55e;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#22c55e;">2) Rainfall (Rainfall_mm) vs Irrigation Need</h3>
#
# <ul>
# <li>Overall, By analyzing and visualizing this Dataset it is determined that Low irrigation need shows the lowest rainfall values.</li>
# <li>Medium and High irrigation needs have higher rainfall, with High having the largest maximum and the strongest spread.</li>
# <li>This indicates that the rainfall alone is not enough to reduce irrigation need—higher irrigation need can still occur with higher rainfall.</li>
# </ul>
# </div>
#
# <!-- SECTION 3 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#0f172a;
#     border-left:5px solid #f59e0b;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#f59e0b;">3) Temperature (C) vs Irrigation Need</h3>
#
# <ul>
# <li>Medium irrigation need has the higher spread of the temperature values.</li>
# <li>High irrigation need shows temperatures that are generally slightly higher than Low, but not the highest overall.</li>
# <li>Temperature does not change in a perfectly straight line, but there is a clear difference between categories.</li>
# </ul>
# </div>
#
# <!-- SECTION 4 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #ef4444;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#ef4444;">4) Humidity vs Irrigation Need</h3>
#
# <ul>
# <li>Low irrigation need has the highest humidity on an average according to this dataset.</li>
# <li>High irrigation need has the lowest humidity values (As the mean  value of it is the smallest).</li>
# <li>Humidity generally decreases as irrigation need increases, suggesting drier air conditions may increase irrigation demand.</li>
# </ul>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Mulching Shield Effect analysis | Impact on High Irrigation Need</p>

# %%
def analyze_mulching_shield(train_df, org_df, target_col):
    import pandas as pd
    from IPython.display import display, HTML

    def mulch_stats(df, label):
        rates = df.groupby('Mulching_Used')[target_col].apply(
            lambda x: (x == 'High').mean() * 100
        )

        multiplier = rates['No'] / rates['Yes']

        return {
            'Dataset': label,
            'High_NoMulch (%)': rates['No'],
            'High_WithMulch (%)': rates['Yes'],
            'Protection_Multiplier': multiplier
        }

    # compute results
    df_mulch = pd.DataFrame([
        mulch_stats(org_df, 'Original'),
        mulch_stats(train_df, 'Train')
    ])

    df_mulch = df_mulch.round(2)
    styled = df_mulch.style.set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#111827"),
            ("color", "#38bdf8"),
            ("font-weight", "bold"),
            ("text-align", "center"),
            ("padding", "10px"),
            ("border", "1px solid #38bdf8")
        ]},
        {"selector": "td", "props": [
            ("background-color", "#0f172a"),
            ("color", "white"),
            ("text-align", "center"),
            ("padding", "8px"),
            ("border", "1px solid #1f2937")
        ]}
    ])

    display(styled)
analyze_mulching_shield(df_train, df_org, target_col)
# Out:
# <style type="text/css">
# #T_70d4f th {
#   background-color: #111827;
#   color: #38bdf8;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
#   border: 1px solid #38bdf8;
# }
# #T_70d4f td {
#   background-color: #0f172a;
#   color: white;
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #1f2937;
# }
# </style>
# <table id="T_70d4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70d4f_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_70d4f_level0_col1" class="col_heading level0 col1" >High_NoMulch (%)</th>
#       <th id="T_70d4f_level0_col2" class="col_heading level0 col2" >High_WithMulch (%)</th>
#       <th id="T_70d4f_level0_col3" class="col_heading level0 col3" >Protection_Multiplier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70d4f_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# <!-- HEADER -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:22px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:20px;
#     font-weight:900;
#     border:2px solid #22c55e;
#     box-shadow:0 0 25px rgba(0,0,0,0.7);
# ">
# 🌿 Mulching Impact Analysis (Original vs Train)
# </div>
#
# <!-- SECTION 1 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #38bdf8;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#38bdf8;">1) Mulch Impact Summary Table (Original vs Train)</h3>
#
# <ul>
# <li>The table compares irrigation “High irrigation with/without mulching” and the protection multiplier for two datasets:</li>
# <li>Original</li>
# <li>Train (synthetic/training data)</li>
# </ul>
# </div>
#
# <!-- SECTION 2 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#1f2937;
#     border-left:5px solid #22c55e;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#22c55e;">2) High Irrigation Without Mulch (High_NoMulch %)</h3>
#
# <ul>
# <li>Original: 5.47%</li>
# <li>Train: 5.85%</li>
# <li>This means the Train data has a slightly higher percentage of “High” irrigation when mulch is not used.</li>
# </ul>
# </div>
#
# <!-- SECTION 3 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#0f172a;
#     border-left:5px solid #f59e0b;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#f59e0b;">3) High Irrigation With Mulch (High_WithMulch %)</h3>
#
# <ul>
# <li>Original: 1.24%</li>
# <li>Train: 0.79%</li>
# <li>This means the Train data shows fewer cases of “High irrigation” even when mulch is used.</li>
# </ul>
# </div>
#
# <!-- SECTION 4 -->
# <div style="
#     margin-top:18px;
#     padding:18px;
#     border-radius:14px;
#     background:#111827;
#     border-left:5px solid #ef4444;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#ef4444;">4) Protection Multiplier</h3>
#
# <ul>
# <li>Original: 4.40</li>
# <li>Train: 7.38</li>
# <li>The Train dataset has a much stronger protection effect (higher multiplier), meaning mulch reduces high-irrigation occurrence more strongly in the Train data than in the Original data.</li>
# </ul>
# </div>
#
# <!-- CONCLUSION -->
# <div style="
#     margin-top:20px;
#     padding:18px;
#     border-radius:14px;
#     background:#0f172a;
#     border:1px solid #22c55e;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
# ">
# <h3 style="color:#22c55e;">Overall Conclusion</h3>
#
# <ul>
# <li>The Train dataset is not identical to the Original:</li>
# <li>It slightly increases High without mulch</li>
# <li>It decreases High with mulch</li>
# <li>It makes mulching protection much stronger (higher multiplier)</li>
# </ul>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Feature Engineering</p>

# %%
def apply_enhanced_feature_engineering(df):
    d = df.copy()
    
    # Original strong features
    high_score = (d["Soil_Moisture"] < 25).astype(int) * 2 + (d["Rainfall_mm"] < 300).astype(int) * 2 + \
                 (d["Temperature_C"] > 30).astype(int) + (d["Wind_Speed_kmh"] > 10).astype(int)
    low_score = (d["Crop_Growth_Stage"] == "Harvest").astype(int) * 2 + (d["Crop_Growth_Stage"] == "Sowing").astype(int) * 2 + \
                (d["Mulching_Used"] == "Yes").astype(int)
    d["physical_score"] = high_score - low_score
    
    # Adaptive rounding
    num_cols = ["Soil_pH", "Soil_Moisture", "Organic_Carbon", "Electrical_Conductivity",
                "Temperature_C", "Humidity", "Rainfall_mm", "Sunlight_Hours",
                "Wind_Speed_kmh", "Field_Area_hectare", "Previous_Irrigation_mm"]
    for col in num_cols:
        max_val = d[col].max()
        decimals = 3 if max_val < 10 else 2 if max_val < 100 else 1
        d[f"{col}_rounded"] = d[col].round(decimals)
    
    # Forensic flags
    d['canyon_low_rain'] = (d['Rainfall_mm'] < 463).astype(int)
    d['canyon_high_rain'] = ((d['Rainfall_mm'] >= 1902) & (d['Rainfall_mm'] <= 2007)).astype(int)
    d['q3_rain_breach_flag'] = ((d['Soil_Moisture'] < 25) & (d['Rainfall_mm'] >= 300)).astype(int)
    d['mulch_shield_interaction'] = (d["Mulching_Used"] == "No").astype(int) * d["Soil_Moisture"]
    d['temp_humidity_ratio'] = d['Temperature_C'] * (1 - d['Humidity']/100)          
    d['rain_moisture_ratio'] = d['Rainfall_mm'] / (d['Soil_Moisture'] + 1)
    d['temp_decimal'] = (d['Temperature_C'] * 10 % 10).astype(int)
    d['humidity_decimal'] = (d['Humidity'] * 10 % 10).astype(int)
    d['rainfall_bin'] = pd.cut(d['Rainfall_mm'], bins=[0, 463, 954, 1467, 2054, 2500], labels=[0,1,2,3,4]).astype(int)
    for g in ['Crop_Type', 'Region']:
        d[f'{g}_mean_rain'] = d.groupby(g)['Rainfall_mm'].transform('mean')
        d[f'{g}_mean_moisture'] = d.groupby(g)['Soil_Moisture'].transform('mean')
    
    return d

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">LightGBM Model Training with In-Fold Target Encoding & Bias Optimization</p>

# %%
print("\n" + "="*80)
print("BUILDING FURTHER IMPROVED LIGHTGBM PIPELINE")
print("="*80)

X_raw = df_train.drop(['id', target_col, 'target_numeric'], axis=1, errors='ignore')
y_numeric = df_train['target_numeric'].values.astype(int)
test_ids = df_test['id'].copy()

cat_features = ["Soil_Type", "Crop_Type", "Crop_Growth_Stage", "Season", "Irrigation_Type", "Water_Source", "Mulching_Used", "Region"]
num_features = ["Soil_pH", "Soil_Moisture", "Organic_Carbon", "Electrical_Conductivity", "Temperature_C", "Humidity", "Rainfall_mm", "Sunlight_Hours", "Wind_Speed_kmh", "Field_Area_hectare", "Previous_Irrigation_mm"]

print("Applying Enhanced Feature Engineering...")
X_full = apply_enhanced_feature_engineering(X_raw)
X_test_full = apply_enhanced_feature_engineering(df_test.drop('id', axis=1))

N_FOLDS = 5
cv = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
oof_predictions = np.zeros((len(X_full), 3))
test_predictions = np.zeros((len(X_test_full), 3))

lgb_hyperparams = {
    'objective': 'multiclass', 'num_class': 3, 'metric': 'multi_logloss',
    'learning_rate': 0.038, 'num_leaves': 255, 'min_child_samples': 35,
    'subsample': 0.88, 'colsample_bytree': 0.68, 'n_estimators': 2600,
    'reg_alpha': 0.08, 'reg_lambda': 0.12,
    'random_state': 42, 'verbose': -1, 'n_jobs': -1
}

print("Training with In-Fold Target Encoding")
for fold_idx, (train_idx, val_idx) in enumerate(cv.split(X_full, y_numeric)):
    X_tr = X_full.iloc[train_idx].copy()
    y_tr = y_numeric[train_idx]
    X_val = X_full.iloc[val_idx].copy()
    y_val = y_numeric[val_idx]
    X_te = X_test_full.copy()
    
    te_cols = cat_features + [c for c in X_full.columns if '_rounded' in c or '_bin' in c or '_decimal' in c]
    encoder = TargetEncoder(target_type="multiclass", random_state=42)
    
    enc_train = pd.DataFrame(encoder.fit_transform(X_tr[te_cols], y_tr).astype(np.float32), index=X_tr.index)
    enc_val = pd.DataFrame(encoder.transform(X_val[te_cols]).astype(np.float32), index=X_val.index)
    enc_test = pd.DataFrame(encoder.transform(X_te[te_cols]).astype(np.float32), index=X_te.index)
    
    enc_cols = [f"target_enc_{i}" for i in range(enc_train.shape[1])]
    enc_train.columns = enc_cols; enc_val.columns = enc_cols; enc_test.columns = enc_cols
    
    base_cols = [c for c in X_full.columns if c not in te_cols]
    X_train_final = pd.concat([X_tr[base_cols], enc_train], axis=1)
    X_val_final = pd.concat([X_val[base_cols], enc_val], axis=1)
    X_test_final = pd.concat([X_te[base_cols], enc_test], axis=1)
    
    sample_weights = compute_sample_weight("balanced", y_tr)
    
    model = lgb.LGBMClassifier(**lgb_hyperparams)
    model.fit(X_train_final, y_tr, sample_weight=sample_weights,
              eval_set=[(X_val_final, y_val)],
              callbacks=[lgb.early_stopping(60, verbose=False)])
    
    oof_predictions[val_idx] = model.predict_proba(X_val_final)
    test_predictions += model.predict_proba(X_test_final) / N_FOLDS
    
    print(f"  Fold {fold_idx+1} BA: {balanced_accuracy_score(y_val, np.argmax(oof_predictions[val_idx], axis=1)):.5f}")

raw_oof = balanced_accuracy_score(y_numeric, np.argmax(oof_predictions, axis=1))
print(f"\nRaw OOF Balanced Accuracy: {raw_oof:.6f}")

# Bias Tuning
print("\nAdvanced Bias Tuning...")
def apply_bias(proba, bias):
    return np.argmax(np.log(np.clip(proba, 1e-15, 1.0)) + bias, axis=1)

def bias_objective(trial):
    bias_vec = np.array([trial.suggest_float(f"b{i}", -2.5, 2.5) for i in range(3)])
    return balanced_accuracy_score(y_numeric, apply_bias(oof_predictions, bias_vec))

study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(bias_objective, n_trials=120, show_progress_bar=False)

best_bias = np.array([study.best_params[f"b{i}"] for i in range(3)])
tuned_oof = study.best_value
print(f"Tuned OOF Balanced Accuracy: {tuned_oof:.6f} (+{tuned_oof-raw_oof:.5f} lift)")

final_preds = apply_bias(test_predictions, best_bias)
submission = pd.DataFrame({'id': test_ids, target_col: [inverse_mapping[p] for p in final_preds]})
submission.to_csv('submission.csv', index=False)
print("submission.csv created sucessfully!")
# Out:
# ...
# BUILDING FURTHER IMPROVED LIGHTGBM PIPELINE
# ...
# Applying Enhanced Feature Engineering...
# Training with In-Fold Target Encoding
#   Fold 1 BA: 0.97296
#   Fold 2 BA: 0.97453
#   Fold 3 BA: 0.97552
#   Fold 4 BA: 0.97298
#   Fold 5 BA: 0.97367
#
# Raw OOF Balanced Accuracy: 0.973932
#
# Advanced Bias Tuning...
# Tuned OOF Balanced Accuracy: 0.979251 (+0.00532 lift)
# submission.csv created sucessfully!

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Lets Visualize Feature Importance</p>

# %%
def save_and_plot_importance(oof_predictions, test_predictions, best_bias, X_train_final, model):
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    def calibrate_probs(probs, bias):
        log_p = np.log(np.clip(probs, 1e-15, 1.0)) + bias
        exp_p = np.exp(log_p)
        return exp_p / exp_p.sum(axis=1, keepdims=True)

    print("\nSaving calibrated probabilities...")

    np.save(
        'oof_probs_final.npy',
        calibrate_probs(oof_predictions, best_bias)
    )

    np.save(
        'test_probs_final.npy',
        calibrate_probs(test_predictions, best_bias)
    )

    print("Ensemble files saved successfully.")

    # FEATURE IMPORTANCE
    imp_df = pd.DataFrame({
        'feature': X_train_final.columns,
        'importance': model.feature_importances_
    })

    imp_df = imp_df.sort_values('importance', ascending=False).head(20)
    plt.style.use("dark_background")

    plt.figure(figsize=(12, 8), facecolor="#0f172a")

    sns.barplot(
        data=imp_df,
        x='importance',
        y='feature',
        palette=['#38bdf8', '#f97316', '#ef4444']
    )

    plt.title(
        'Top 20 Important Features',
        fontsize=18,
        fontweight='bold',
        color='white',
        pad=15
    )

    plt.xlabel("Importance", color="white")
    plt.ylabel("Feature", color="white")

    plt.gca().set_facecolor("#111827")
    plt.gca().tick_params(colors='white')

    plt.grid(True, alpha=0.2)

    plt.tight_layout()
    plt.show()
save_and_plot_importance(
    oof_predictions,
    test_predictions,
    best_bias,
    X_train_final,
    model
)
# Out:
# Saving calibrated probabilities...
# Ensemble files saved successfully.

# %% [markdown]
# <!-- MAIN TITLE -->
# <div style="
#     background: linear-gradient(135deg,#0f172a,#7c2d12,#111827);
#     color:#ffffff;
#     text-align:center;
#     padding:24px;
#     border-radius:18px;
#     font-family:'Poppins',sans-serif;
#     font-size:22px;
#     font-weight:900;
#     border:2px solid #22c55e;
#     box-shadow:0 0 30px rgba(0,0,0,0.7);
#     letter-spacing:1px;
# ">
# 🌾 Conclusion
# </div>
#
# <!-- CONCLUSION BOX -->
# <div style="
#     margin-top:22px;
#     padding:24px;
#     border-radius:18px;
#     background:#111827;
#     border:1px solid #374151;
#     color:#ffffff;
#     font-family:'Poppins',sans-serif;
#     line-height:1.8;
#     box-shadow:0 10px 35px rgba(0,0,0,0.6);
# ">
#
# <p>
# This notebook tells how <b>machine learning</b> can support more sustainable irrigation decisions in agriculture. By combining meaningful <b>EDA</b>and targeted feature engineering<b>LightGBM</b> with in-fold target encoding and bias tuning, I built a generalizable model which is capable of predicting irrigation needs with great results.
# </p>
#
# </div>
#
# <!-- INSIGHT SECTION -->
# <div style="
#     margin-top:20px;
#     padding:20px;
#     border-radius:15px;
#     background:#0f172a;
#     border-left:5px solid #38bdf8;
# ">
# <h3 style="color:#38bdf8;">🔍 Key Insights from Analysis</h3>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li>The analysis highlighted the <b>strong protective effect of mulching</b> in reducing irrigation demand.</li>
# <li><b>Rainfall patterns</b> play very important role in determining irrigation necessarily.</li>
# <li><b>Interaction between soil and weather features</b> improves prediction.</li>
# </ul>
# </div>
#
# <!-- MODEL SECTION -->
# <div style="
#     margin-top:20px;
#     padding:20px;
#     border-radius:15px;
#     background:#1f2937;
#     border-left:5px solid #22c55e;
# ">
# <h3 style="color:#22c55e;">🤖 Model Performance & Robustness</h3>
#
# <p style="color:#ffffff;">
# Finally, the model successfully balances real-world agricultural variability while it maintains the performance. Techniques such as <b>LightGBM optimization, target encoding, and bias tuning</b> helped to improve generalization across unseen data.
# </p>
# </div>
#
# <!-- IMPACT SECTION -->
# <div style="
#     margin-top:20px;
#     padding:20px;
#     border-radius:15px;
#     background:#111827;
#     border-left:5px solid #f59e0b;
# ">
# <h3 style="color:#f59e0b;">💧 Real-World Impact</h3>
#
# <p style="color:#ffffff;">
# Effective irrigation prediction contributes to:
# </p>
#
# <ul style="color:#ffffff; line-height:1.8;">
# <li><b>Water conservation</b>avoid unnecessary irrigation</li>
# <li><b>It reduce Cost</b> for farmers and agricultural systems</li>
# <li><b>By analyzing thsi Dataset crop productivity can be improved</b> through optimized water usage</li>
# </ul>
# </div>

# %% [markdown]
# # <p style="background-color:#7c2d12;font-family:'Georgia',serif;font-size:90%;text-align:center;color:#fde68a;border-radius:1000px 50px;border:4px solid #22c55e;padding:20px 40px;margin:15px 0;">Thank You!</p>
