# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/a-bit-better/__results__.html
# /kaggle/input/a-bit-better/bbox3
# /kaggle/input/a-bit-better/submission.csv
# /kaggle/input/a-bit-better/__notebook__.ipynb
# /kaggle/input/a-bit-better/__output__.json
# /kaggle/input/a-bit-better/custom.css
# /kaggle/input/new-year-same-old-bbox/__results__.html
# /kaggle/input/new-year-same-old-bbox/bbox3
# /kaggle/input/new-year-same-old-bbox/submission.csv
# /kaggle/input/new-year-same-old-bbox/__notebook__.ipynb
# /kaggle/input/new-year-same-old-bbox/__output__.json
# /kaggle/input/new-year-same-old-bbox/custom.css
# /kaggle/input/mysteriously-slightly-better-solution/__results__.html
# /kaggle/input/mysteriously-slightly-better-solution/submission.csv
# /kaggle/input/mysteriously-slightly-better-solution/__notebook__.ipynb
# /kaggle/input/mysteriously-slightly-better-solution/__output__.json
# /kaggle/input/mysteriously-slightly-better-solution/custom.css
# /kaggle/input/santa-2025/sample_submission.csv
# /kaggle/input/santa-submission-happy-new-year/__results__.html
# /kaggle/input/santa-submission-happy-new-year/bbox3
# /kaggle/input/santa-submission-happy-new-year/submission.csv
# /kaggle/input/santa-submission-happy-new-year/__notebook__.ipynb
# /kaggle/input/santa-submission-happy-new-year/__output__.json
# /kaggle/input/santa-submission-happy-new-year/custom.css
# /kaggle/input/santa-2025-quick-ensemble/__results__.html
# /kaggle/input/santa-2025-quick-ensemble/submission.csv
# /kaggle/input/santa-2025-quick-ensemble/__notebook__.ipynb
# /kaggle/input/santa-2025-quick-ensemble/__output__.json
# /kaggle/input/santa-2025-quick-ensemble/custom.css
# /kaggle/input/santa-2025-quick-ensemble/.virtual_documents/__notebook_source__.ipynb
# /kaggle/input/santa-submission/kaggle_bbox_2026-01-04-09-23.zip
# /kaggle/input/santa-submission/__results__.html
# /kaggle/input/santa-submission/bbox3
# /kaggle/input/santa-submission/bbox_experiments.log
# /kaggle/input/santa-submission/submission.csv
# /kaggle/input/santa-submission/__notebook__.ipynb
# /kaggle/input/santa-submission/__output__.json
# /kaggle/input/santa-submission/custom.css
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r10_i1.csv
# /kaggle/input/magic-fast-backprop/__results__.html
# /kaggle/input/magic-fast-backprop/submission.csv
# /kaggle/input/magic-fast-backprop/__notebook__.ipynb
# /kaggle/input/magic-fast-backprop/__output__.json
# /kaggle/input/magic-fast-backprop/custom.css

# %%
import subprocess
import re
import shutil
import os

# --- 1. Setup Paths & Copy Files ---
INPUT_SUB = '/kaggle/input/magic-fast-backprop/submission.csv'
INPUT_BIN = '/kaggle/input/a-bit-better/bbox3'
WORKING_DIR = '/kaggle/working/'

print("📂 Setting up environment...")

# Copy submission to working directory
if os.path.exists(INPUT_SUB):
    shutil.copy(INPUT_SUB, os.path.join(WORKING_DIR, 'submission.csv'))
    print(f"✅ Copied {INPUT_SUB} -> ./submission.csv")

# Copy executable to working directory
if os.path.exists(INPUT_BIN):
    shutil.copy(INPUT_BIN, os.path.join(WORKING_DIR, 'bbox3'))
    print(f"✅ Copied {INPUT_BIN} -> ./bbox3")

# Set executable permissions
os.chmod('./bbox3', 0o755)
print("✅ Permissions set for ./bbox3")

import math
import pandas as pd
import numpy as np
from numba import njit

@njit
def make_polygon_template():
    tw=0.15; th=0.2; bw=0.7; mw=0.4; ow=0.25
    tip=0.8; t1=0.5; t2=0.25; base=0.0; tbot=-th
    x=np.array([0,ow/2,ow/4,mw/2,mw/4,bw/2,tw/2,tw/2,-tw/2,-tw/2,-bw/2,-mw/4,-mw/2,-ow/4,-ow/2],np.float64)
    y=np.array([tip,t1,t1,t2,t2,base,base,tbot,tbot,base,base,t2,t2,t1,t1],np.float64)
    return x,y

@njit
def score_group(xs,ys,degs,tx,ty):
    n=xs.size; V=tx.size
    mnx=1e300; mny=1e300; mxx=-1e300; mxy=-1e300
    for i in range(n):
        r=degs[i]*math.pi/180.0
        c=math.cos(r); s=math.sin(r)
        xi=xs[i]; yi=ys[i]
        for j in range(V):
            X=c*tx[j]-s*ty[j]+xi
            Y=s*tx[j]+c*ty[j]+yi
            if X<mnx: mnx=X
            if X>mxx: mxx=X
            if Y<mny: mny=Y
            if Y>mxy: mxy=Y
    side=max(mxx-mnx,mxy-mny)
    return side*side/ n

def strip(a):
    return np.array([float(str(v).replace("s","")) for v in a],np.float64)

def all_csv_files():
    out=[]
    for f in subs:
        out += glob.glob(f + "/*.csv", recursive=False)
    return out

from decimal import Decimal, getcontext

from shapely import affinity
from shapely.geometry import Polygon

# Set precision for Decimal
getcontext().prec = 25
scale_factor = Decimal("1e18")

class ChristmasTree:
    """Represents a single, rotatable Christmas tree of a fixed size."""

    def __init__(self, center_x="0", center_y="0", angle="0"):
        """Initializes the Christmas tree with a specific position and rotation."""
        self.center_x = Decimal(center_x)
        self.center_y = Decimal(center_y)
        self.angle = Decimal(angle)

        trunk_w = Decimal("0.15")
        trunk_h = Decimal("0.2")
        base_w = Decimal("0.7")
        mid_w = Decimal("0.4")
        top_w = Decimal("0.25")
        tip_y = Decimal("0.8")
        tier_1_y = Decimal("0.5")
        tier_2_y = Decimal("0.25")
        base_y = Decimal("0.0")
        trunk_bottom_y = -trunk_h

        initial_polygon = Polygon(
            [
                # Start at Tip
                (Decimal("0.0") * scale_factor, tip_y * scale_factor),
                # Right side - Top Tier
                (top_w / Decimal("2") * scale_factor, tier_1_y * scale_factor),
                (top_w / Decimal("4") * scale_factor, tier_1_y * scale_factor),
                # Right side - Middle Tier
                (mid_w / Decimal("2") * scale_factor, tier_2_y * scale_factor),
                (mid_w / Decimal("4") * scale_factor, tier_2_y * scale_factor),
                # Right side - Bottom Tier
                (base_w / Decimal("2") * scale_factor, base_y * scale_factor),
                # Right Trunk
                (trunk_w / Decimal("2") * scale_factor, base_y * scale_factor),
                (trunk_w / Decimal("2") * scale_factor, trunk_bottom_y * scale_factor),
                # Left Trunk
                (-(trunk_w / Decimal("2")) * scale_factor, trunk_bottom_y * scale_factor),
                (-(trunk_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Bottom Tier
                (-(base_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Middle Tier
                (-(mid_w / Decimal("4")) * scale_factor, tier_2_y * scale_factor),
                (-(mid_w / Decimal("2")) * scale_factor, tier_2_y * scale_factor),
                # Left side - Top Tier
                (-(top_w / Decimal("4")) * scale_factor, tier_1_y * scale_factor),
                (-(top_w / Decimal("2")) * scale_factor, tier_1_y * scale_factor),
            ]
        )
        rotated = affinity.rotate(initial_polygon, float(self.angle), origin=(0, 0))
        self.polygon = affinity.translate(
            rotated, xoff=float(self.center_x * scale_factor), yoff=float(self.center_y * scale_factor)
        )

import pandas as pd
import numpy as np
from decimal import Decimal
from shapely.strtree import STRtree


def to_str(x: Decimal):
    return f"s{float(x)}"


def load_configuration_from_df(n, existing_df):
    """
    Load existing configuration from submission CSV.
    """
    group_data = existing_df[existing_df["id"].str.startswith(f"{n:03d}_")]
    trees = []
    for _, row in group_data.iterrows():
        x = row["x"][1:]  # Remove 's' prefix
        y = row["y"][1:]
        deg = row["deg"][1:]
        trees.append(ChristmasTree(x, y, deg))
    return trees

def get_score(trees, n=None):
    xys = np.concatenate([np.asarray(t.polygon.exterior.xy).T / 1e18 for t in trees])
    min_x, min_y = xys.min(axis=0)
    max_x, max_y = xys.max(axis=0)
    score = max(max_x - min_x, max_y - min_y) ** 2
    if n is not None:
        score /= n
    return score

def has_overlap(trees):
    """Check if any trees overlap"""
    if len(trees) <= 1:
        return False

    polygons = [t.polygon for t in trees]
    tree_index = STRtree(polygons)

    for i, poly in enumerate(polygons):
        indices = tree_index.query(poly)
        for idx in indices:
            if idx == i:
                continue
            if poly.intersects(polygons[idx]) and not poly.touches(polygons[idx]):
                return True
    return False

import pandas as pd

def eval_df_sub(df, verb):
    failed = []
    total_score = 0.0
    for n in range(1, 201):
        trees = load_configuration_from_df(n, df)
        score = get_score(trees, n)
        total_score += score
        if verb:
            print(f"{n:3}  {score:.6f}")
        if has_overlap(trees):
            failed.append(n)

    if len(failed) == 0:
        print("Overlap check was succesfull")
    else:
        print("Overlap check failed for", *failed)

    print(f"Total score: {total_score:.12f}")
    return total_score


IMPROVEMENT_TARGET = 0.00001

def main():
    # Read in current ensemble output and check for overlaps
    df = pd.read_csv("submission.csv")
    target_score = eval_df_sub(df, False)
    new_score = target_score
    target_score = target_score - IMPROVEMENT_TARGET
    
    print("Starting bbox3 runs")
    
    import subprocess
    import random
    
    while new_score >= target_score:
        random.seed() # Use a random seed every time; add fixed number for repeatability
        n =  str(random.randint(100,1000))
        r = str(random.randint(10,100))
        print(f"#### Running bbox3 for n={n} r={r}")
        subprocess.run(["./bbox3", 
                        "-n", str(random.randint(100,1000)), 
                        "-r", str(random.randint(10,100))])
        df = pd.read_csv("submission.csv")
        new_score = eval_df_sub(df, False)

main()
# Out:
# 📂 Setting up environment...
# ✅ Copied /kaggle/input/magic-fast-backprop/submission.csv -> ./submission.csv
# ✅ Copied /kaggle/input/a-bit-better/bbox3 -> ./bbox3
# ✅ Permissions set for ./bbox3
# Overlap check was succesfull
# Total score: 70.897092480731
# Starting bbox3 runs
# #### Running bbox3 for n=186 r=14
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897092
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=194: 0.340203053616 -> 0.340203033891 (0.0000% better) 🏆
# [0] n=193: 0.340165565244 -> 0.340165475389 (0.0000% better) 🏆
# [3] n=110: 0.337619638694 -> 0.337619581162 (0.0000% better) 🏆
# [0] n=181: 0.330200318761 -> 0.330199412433 (0.0003% better) 🏆
# [0] n=178: 0.335408729016 -> 0.335408533716 (0.0001% better) 🏆
# [0] n=177: 0.337302986613 -> 0.337302684035 (0.0001% better) 🏆
# [3] n=107: 0.346235106577 -> 0.346234964177 (0.0000% better) 🏆
# [0] n=155: 0.332096894537 -> 0.332096860713 (0.0000% better) 🏆
# [0] n=152: 0.338546404126 -> 0.338546172470 (0.0001% better) 🏆
# [1] n=  8: 0.385412521301 -> 0.385412317206 (0.0001% better) 🏆
# [2] n=116: 0.344467046759 -> 0.344466933445 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897092480731
# Final Score:   70.897090184123
# Improvement:   0.000002296608 (0.00%)
# Total Time:    319.3s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897090184123
# #### Running bbox3 for n=412 r=78
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897090
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [1] n=150: 0.337080849417 -> 0.337080824629 (0.0000% better) 🏆
# [0] n=180: 0.332006387875 -> 0.332005808159 (0.0002% better) 🏆
# [0] n=163: 0.337614256291 -> 0.337614159951 (0.0000% better) 🏆
# [0] n= 61: 0.358500163024 -> 0.358500151481 (0.0000% better) 🏆
# [3] n=107: 0.346234964177 -> 0.346234634146 (0.0001% better) 🏆
# [2] n= 66: 0.358946460548 -> 0.358946254552 (0.0001% better) 🏆
# [2] n= 65: 0.363827957799 -> 0.363827733768 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897090184123
# Final Score:   70.897088711678
# Improvement:   0.000001472445 (0.00%)
# Total Time:    602.9s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897088711678
# #### Running bbox3 for n=460 r=64
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897089
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [2] n= 84: 0.352165178639 -> 0.352165085882 (0.0000% better) 🏆
# [0] n=182: 0.330049647940 -> 0.330049590077 (0.0000% better) 🏆
# [0] n=180: 0.332005808159 -> 0.332005613748 (0.0001% better) 🏆
# [0] n=177: 0.337302684035 -> 0.337302417462 (0.0001% better) 🏆
# [1] n=111: 0.345119618198 -> 0.345119612987 (0.0000% better) 🏆
# [0] n=157: 0.342786062637 -> 0.342786005529 (0.0000% better) 🏆
# [0] n=154: 0.334173945223 -> 0.334173944677 (0.0000% better) 🏆
# [2] n= 76: 0.352611849547 -> 0.352611825447 (0.0000% better) 🏆
# [0] n= 55: 0.355041494219 -> 0.355041432418 (0.0000% better) 🏆
# [0] n= 30: 0.360885010096 -> 0.360885009459 (0.0000% better) 🏆
# [2] n= 67: 0.353862632865 -> 0.353862552218 (0.0000% better) 🏆
# [3] n=139: 0.341496460736 -> 0.341496208414 (0.0001% better) 🏆
# [1] n= 90: 0.344666878117 -> 0.344666773645 (0.0000% better) 🏆
# [1] n= 89: 0.348127391300 -> 0.348127035497 (0.0001% better) 🏆
# [1] n= 87: 0.355304096143 -> 0.355303975520 (0.0000% better) 🏆
# [3] n=129: 0.341487040148 -> 0.341487033003 (0.0000% better) 🏆
# [3] n=121: 0.351592553408 -> 0.351592000741 (0.0002% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897088711678
# Final Score:   70.897086476990
# Improvement:   0.000002234688 (0.00%)
# Total Time:    847.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897086476990
# #### Running bbox3 for n=715 r=66
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897086
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [2] n= 84: 0.352165085882 -> 0.352165053137 (0.0000% better) 🏆
# [1] n=110: 0.337619581162 -> 0.337619422819 (0.0000% better) 🏆
# [2] n= 81: 0.362295354977 -> 0.362295339466 (0.0000% better) 🏆
# [1] n=106: 0.342499912548 -> 0.342499840702 (0.0000% better) 🏆
# [3] n=145: 0.345558423676 -> 0.345558356348 (0.0000% better) 🏆
# [3] n=144: 0.342295673048 -> 0.342295672681 (0.0000% better) 🏆
# [0] n=181: 0.330199412433 -> 0.330199037972 (0.0001% better) 🏆
# [0] n=180: 0.332005613748 -> 0.332005127851 (0.0001% better) 🏆
# [2] n= 68: 0.353649642961 -> 0.353649606713 (0.0000% better) 🏆
# [2] n= 66: 0.358946254552 -> 0.358946243154 (0.0000% better) 🏆
# [0] n=172: 0.340957031836 -> 0.340956989495 (0.0000% better) 🏆
# [3] n=139: 0.341496208414 -> 0.341496092820 (0.0000% better) 🏆
# [1] n= 90: 0.344666773645 -> 0.344666712566 (0.0000% better) 🏆
# [2] n= 49: 0.366771127585 -> 0.366771072502 (0.0000% better) 🏆
# [3] n=131: 0.337854888331 -> 0.337854384512 (0.0001% better) 🏆
# [2] n=  8: 0.385412317206 -> 0.385412239439 (0.0000% better) 🏆
# [3] n=127: 0.346743374092 -> 0.346743319221 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897086476990
# Final Score:   70.897084312290
# Improvement:   0.000002164699 (0.00%)
# Total Time:    124.3s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897084312290
# #### Running bbox3 for n=781 r=28
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897084
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [1] n=112: 0.348988561364 -> 0.348988513362 (0.0000% better) 🏆
# [0] n=182: 0.330049590077 -> 0.330049504577 (0.0000% better) 🏆
# [0] n=179: 0.333598411939 -> 0.333598378890 (0.0000% better) 🏆
# [0] n=172: 0.340956989495 -> 0.340956987403 (0.0000% better) 🏆
# [1] n=108: 0.343595869397 -> 0.343595791348 (0.0000% better) 🏆
# [1] n=106: 0.342499840702 -> 0.342499730245 (0.0000% better) 🏆
# [1] n=101: 0.350485468232 -> 0.350485464767 (0.0000% better) 🏆
# [1] n= 93: 0.354494662279 -> 0.354494662111 (0.0000% better) 🏆
# [1] n= 88: 0.351266749580 -> 0.351266630243 (0.0000% better) 🏆
# [1] n= 87: 0.355303975520 -> 0.355303858215 (0.0000% better) 🏆
# [3] n=131: 0.337854384512 -> 0.337854176639 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897084312290
# Final Score:   70.897083506992
# Improvement:   0.000000805298 (0.00%)
# Total Time:    865.0s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897083506992
# #### Running bbox3 for n=866 r=46
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.897084
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=194: 0.340203033891 -> 0.340202993577 (0.0000% better) 🏆
# [0] n=158: 0.343862007081 -> 0.343861831458 (0.0001% better) 🏆
# [3] n= 71: 0.352255382628 -> 0.352255292878 (0.0000% better) 🏆
# [2] n=142: 0.343729361454 -> 0.343729352049 (0.0000% better) 🏆
# [3] n= 68: 0.353649606713 -> 0.353649368732 (0.0001% better) 🏆
# [3] n= 66: 0.358946243154 -> 0.358946032318 (0.0001% better) 🏆
# [3] n= 65: 0.363827733768 -> 0.363827706876 (0.0000% better) 🏆
# [0] n=  8: 0.385412239439 -> 0.385412046333 (0.0001% better) 🏆
# [1] n= 90: 0.344666712566 -> 0.344666541784 (0.0000% better) 🏆
# [1] n= 87: 0.355303858215 -> 0.355303564791 (0.0001% better) 🏆
# [2] n=121: 0.351592000741 -> 0.351591783311 (0.0001% better) 🏆
# [2] n=117: 0.341963393931 -> 0.341963390156 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.897083506992
# Final Score:   70.897081837674
# Improvement:   0.000001669318 (0.00%)
# Total Time:    320.8s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.897081837674
